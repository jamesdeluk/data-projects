# %%
import pandas as pd

# %%
url='https://drive.google.com/uc?id=1wLuyOzM81IjBSwLflfB54CSx6KxY5NAe'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#                        id                      name  popularity  duration_ms  \
# 0  1PWnjvzT5Jhpfnh96DRNDh           Best I Ever Had          51       258800
# 1  32nmTtZNtJq2LQQJlYc96h  My Only Wish (This Year)           4       254720
# 2  6nx1JCehhu4N9j5qNALyTu     The Crunge - Remaster          34       197704
# 3  4pW4DF1119GLHiuWE7Jcb4      Thank You - Remaster          48       289485
# 4  1pYKzfOlpHWtVUiEIu4Vn7           What's My Name?          53       263173
#
#    explicit               artists  \
# 0         0             ['Drake']
# 1         0    ['Britney Spears']
# 2         0      ['Led Zeppelin']
# 3         0      ['Led Zeppelin']
# 4         0  ['Rihanna', 'Drake']
#
#                                           id_artists release_date  \
# 0                         ['3TVXtAsR1Inumwj472S9r4']   2009-01-01
# 1                         ['26dSoYclwsYLMAKD3tpOr4']   2007-11-30
# 2                         ['36QJpDe2go2KgaRleHCDTp']   1973-03-28
# 3                         ['36QJpDe2go2KgaRleHCDTp']   1969-10-22
# 4  ['5pKCCKE2ajJHZ9KAiaK11H', '3TVXtAsR1Inumwj472...   2010-11-15
#
#    danceability  energy  ...  mode  speechiness  acousticness  \
# 0         0.441   0.904  ...     1       0.3590         0.102
# 1         0.667   0.715  ...     1       0.0269         0.184
# 2         0.531   0.798  ...     1       0.1480         0.132
# 3         0.292   0.306  ...     1       0.0547         0.184
# 4         0.695   0.782  ...     1       0.0629         0.223
#
#    instrumentalness  liveness  valence    tempo  time_signature  main_artist  \
# 0            0.0000    0.1960    0.529  161.740               4        Drake
# 1            0.0000    0.1860    0.678  147.064               4      Britney
# 2            0.0000    0.3560    0.852  112.609               5     Zeppelin
# 3            0.0046    0.1440    0.131   79.406               4     Zeppelin
# 4            0.0000    0.0773    0.595   99.992               4        Drake
#
#    duration_mins
# 0           4.31
# 1           4.25
# 2           3.30
# 3           4.82
# 4           4.39
#
# [5 rows x 22 columns]

# %%
df.describe()
# Out:
#        popularity   duration_ms    explicit  danceability      energy  \
# count   636.00000  6.360000e+02  636.000000    636.000000  636.000000
# mean     51.97327  2.799651e+05    0.375786      0.556667    0.644586
# std      17.36802  1.146586e+05    0.484706      0.183620    0.198221
# min       0.00000  9.837300e+04    0.000000      0.177000    0.172000
# 25%      40.00000  2.163600e+05    0.000000      0.405500    0.487750
# 50%      53.00000  2.552265e+05    0.000000      0.545000    0.661000
# 75%      64.00000  3.113078e+05    1.000000      0.704000    0.824000
# max      91.00000  1.758307e+06    1.000000      0.963000    0.979000
#
#               key    loudness        mode  speechiness  acousticness  \
# count  636.000000  636.000000  636.000000   636.000000    636.000000
# mean     4.687107   -8.618330    0.691824     0.129658      0.203935
# std      3.530460    3.164313    0.462103     0.128858      0.232138
# min      0.000000  -18.524000    0.000000     0.024500      0.000052
# 25%      2.000000  -10.384250    0.000000     0.043650      0.031850
# 50%      4.000000   -8.435000    1.000000     0.066150      0.103000
# 75%      8.000000   -6.387500    1.000000     0.170000      0.300000
# max     11.000000   -1.304000    1.000000     0.730000      0.970000
#
#        instrumentalness    liveness     valence       tempo  time_signature
# count        636.000000  636.000000  636.000000  636.000000      636.000000
# mean           0.072349    0.210039    0.472629  119.558011        3.926101
# std            0.201934    0.181720    0.237876   29.509409        0.411501
# min            0.000000    0.028600    0.037100   65.041000        1.000000
# 25%            0.000000    0.098650    0.293500   96.131000        4.000000
# 50%            0.000085    0.138000    0.448000  113.879500        4.000000
# 75%            0.011900    0.252000    0.662000  141.657500        4.000000
# max            0.949000    0.967000    0.976000  205.470000        5.000000

# %%
df['duration_mins'] = df['duration_ms'] / 1000 / 60
df['duration_mins'] = round(df['duration_mins'], 2)
df[['name', 'artists', 'duration_mins']].sort_values(by='duration_mins', ascending=False)
# Out:
#                                                   name  \
# 416  Dazed and Confused - (Live at MSG 1973) [Remas...
# 30            Dazed and Confused - Live in Paris, 1969
# 450   Whole Lotta Love - (Live at MSG 1973) [Remaster]
# 383                     In My Time of Dying - Remaster
# 63                 In My Time of Dying - 1990 Remaster
# ..                                                 ...
# 499                             Bron-Yr-Aur - Remaster
# 329                        Bron-Yr-Aur - 1993 Remaster
# 181                Black Mountain Side - 1993 Remaster
# 529                             Summers Over Interlude
# 120                Moby Dick - Intro / Outro Rough Mix
#
#                        artists  duration_mins
# 416           ['Led Zeppelin']          29.31
# 30            ['Led Zeppelin']          15.03
# 450           ['Led Zeppelin']          13.87
# 383           ['Led Zeppelin']          11.14
# 63            ['Led Zeppelin']          11.09
# ..                         ...            ...
# 499           ['Led Zeppelin']           2.11
# 329           ['Led Zeppelin']           2.11
# 181           ['Led Zeppelin']           2.09
# 529  ['Drake', 'Majid Jordan']           1.77
# 120           ['Led Zeppelin']           1.64
#
# [636 rows x 3 columns]

# %%
# df[df['release_date'].str.match('1970')]
# df[df['release_date'] == '1970']
df['release_date'] = pd.to_datetime(df['release_date'],format='ISO8601')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(x='release_date', data=df, bins=20)

# %%
sns.stripplot(x='main_artist', y='popularity', data=df, s=3)
plt.ylim(0,100)
plt.show()

# %%
audio_columns = ['popularity', 'duration_mins', 'key', 'danceability', 'energy', 'loudness',
                 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
                 'time_signature']
for column in audio_columns:
    sns.stripplot(x='main_artist', y = column, data=df, s=3)
    plt.title(column)
    plt.show()
    print('\n')

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Pull out the main artist as the target to be predicted and the audio columns
y = df['main_artist']
X = df[audio_columns]

# Instantiate and fit a model
lr = LogisticRegression(solver='liblinear')
lr.fit(X, y)

# Calculate the accuracy score (%)
lr.score(X,y)*100.0
# Out:
# 91.98113207547169

# %%
# Pull out the main artist as the target to be predicted and the audio columns
y = df['name']
X = df[audio_columns]

# Instantiate and fit a model
lr = LogisticRegression(solver='liblinear')
lr.fit(X, y)

# Calculate the accuracy score (%)
lr.score(X,y)*100.0
# Out:
# 44.81132075471698
