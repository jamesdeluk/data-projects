# %% [markdown]
# https://console.cloud.google.com/apis/api/youtube.googleapis.com/quotas?inv=1&invt=AbmojA&project=ivory-haven-447608-q3

# %%
import csv
import os
import requests
from youtube_transcript_api import YouTubeTranscriptApi
# %load_ext dotenv
# %dotenv
from dotenv import load_dotenv
load_dotenv()
API_KEY = os.environ.get('API_KEY')

# %%
max_results = 50

# %%
def load_channels(filename="channels.csv"):
    channels = []
    with open(filename, "r") as f:
        reader = csv.reader(f)
        for row in reader:
            username = row[0].strip()
            channel_id = row[1].strip()
            category = row[2].strip()
            channels.append((username, channel_id, category))
    return channels

def save_channel(username, channel_id, filename="channels.csv"):
    with open(filename, "a", newline="") as f:
        writer = csv.writer(f)
        writer.writerow([username, channel_id])

def get_channel_id(username):
    url = f"https://www.googleapis.com/youtube/v3/search?part=snippet&type=channel&q={username}&key={API_KEY}"
    response = requests.get(url)
    if response.status_code == 200:
        results = response.json().get("items", [])
        if results:
            return results[0]["id"]["channelId"]
        else:
            print(f"No channel found for username: {username}")
            return None
    else:
        print(f"Error fetching channel ID for username {username}: {response.json()}")
        return None

def get_channel_videos(channel_id, max_results=max_results):
    url = f"https://www.googleapis.com/youtube/v3/search?key={API_KEY}&channelId={channel_id}&part=snippet&type=video&order=date&maxResults={max_results}"
    response = requests.get(url)
    if response.status_code != 200:
        print(f"Error fetching videos for channel {channel_id}: {response.json()}")
        return []
    return response.json().get("items", [])

def is_video_downloaded(video_id, history_file="history.txt"):
    try:
        with open(history_file, "r") as f:
            downloaded_videos = f.read().splitlines()
        return video_id in downloaded_videos
    except FileNotFoundError:
        return False

def mark_video_as_downloaded(video_id, history_file="history.txt"):
    with open(history_file, "a") as f:
        f.write(video_id + "\n")

def download_subtitles(video_id, username, video_title, date, category):
    try:
        transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=["en"])
        save_transcript(video_id, username, video_title, transcript, date, category)
        mark_video_as_downloaded(video_id)
    except Exception as e:
        print(f"No subtitles available for video {video_id}: {e}")

def save_transcript(video_id, username, video_title, transcript, date, category):
    word_count = sum(len(entry['text'].split()) for entry in transcript)
    username = "".join(c for c in username if c.isalnum() or c in " -_")
    video_title = "".join(c for c in video_title if c.isalnum() or c in " -_")
    filename = f"{date} - {category} - {username} - {video_title} - {word_count} words - [{video_id}].txt"
    if category == "Summary":
        folder = "subtitles-summary"
    elif word_count < 500:
        folder = "subtitles-short"
    elif word_count >= 500 and word_count < 2000:
        folder = "subtitles-medium"
    else:
        folder = "subtitles"

    with open(f"{folder}/{filename}", "w", encoding="utf-8") as f:
        for entry in transcript:
            f.write(f"{entry['text']}\n")
    print(f"Subtitles saved as: {filename}")

def monitor_channels():
    channels = load_channels()
    for username, channel_id, category in channels:
        if channel_id == '':
            print(f"Resolving username {username} to channel ID...")
            resolved_id = get_channel_id(username[1:])
            if resolved_id:
                save_channel(username, resolved_id)
                channel_id = resolved_id
            else:
                print(f"Could not resolve username: {username}")
                continue

        print(f"Checking channel: {channel_id}")
        videos = get_channel_videos(channel_id)
        for video in videos:
            video_id = video["id"]["videoId"]
            video_title = video["snippet"]["title"]
            date = video["snippet"]["publishedAt"].split("T")[0]
            if not is_video_downloaded(video_id):
                print(f"Fetching subtitles for video: {video_title} ({video_id})")
                download_subtitles(video_id, username, video_title, date, category)
            else:
                print(f"Subtitles for video {video_id} already downloaded.")

    print("End")

if __name__ == "__main__":
    monitor_channels()
# Out:
# Checking channel: UCGLcx_fFZ3GlLXO5anHSm9w
# Subtitles for video w9oRziQjcpg already downloaded.
# Subtitles for video o6aLQaybM8s already downloaded.
# Subtitles for video PWr1VGn1-Ms already downloaded.
# Subtitles for video AmaLiqo-YvQ already downloaded.
# Subtitles for video NzrsuUCKz98 already downloaded.
# Subtitles for video B8C_hvK8f70 already downloaded.
# Subtitles for video zC5DJ7hIvw4 already downloaded.
# Subtitles for video lgwBccZpSu0 already downloaded.
# Subtitles for video BTbbwyUkv5U already downloaded.
# Subtitles for video D6BN7Sq6Pg4 already downloaded.
# Subtitles for video wEWloTHvEJg already downloaded.
# Subtitles for video 6G17p_ojaiE already downloaded.
# Subtitles for video 8UgXHzzLMZs already downloaded.
# Subtitles for video FQYGid5uCPk already downloaded.
# Subtitles for video vzqWGeZ0X1M already downloaded.
# Subtitles for video ZskBC5Ii1Oo already downloaded.
# Subtitles for video Joc60JtSWJI already downloaded.
# Subtitles for video QDxWuEVTODA already downloaded.
# Subtitles for video _KkjStWBhYM already downloaded.
# Subtitles for video Y8OMXWfbRsk already downloaded.
# Subtitles for video sx3aYbXYehk already downloaded.
# Subtitles for video ULOp4Awh4oI already downloaded.
# Subtitles for video aLvRC_xpjMk already downloaded.
# Subtitles for video 9ivYGQOheMU already downloaded.
# Subtitles for video 03n2VIgtZ2I already downloaded.
# Subtitles for video I-ZSEcRZSsE already downloaded.
# Subtitles for video dT1iV8uN1nk already downloaded.
# Subtitles for video cal4yt9hDtY already downloaded.
# Subtitles for video AlXgh4YAC5M already downloaded.
# Subtitles for video 44ACKKfolFE already downloaded.
# Subtitles for video WY2ODyuLrFg already downloaded.
# Subtitles for video ZH2g2x5FqKE already downloaded.
# Subtitles for video 1xQj4KnNPZw already downloaded.
# Subtitles for video dihwDj_o5LA already downloaded.
# Subtitles for video _WPuMsk5DmA already downloaded.
# Subtitles for video 9MZ1RNsik0Q already downloaded.
# Subtitles for video Jph0SJwNrOg already downloaded.
# Subtitles for video OoEQhBduyTY already downloaded.
# Subtitles for video Uoj0n-_IaX8 already downloaded.
# Subtitles for video HzS_BIYCzv4 already downloaded.
# Subtitles for video SJlDTK3vlHQ already downloaded.
# Subtitles for video 9plXlWwHRZg already downloaded.
# Subtitles for video fa3tW0fIb8w already downloaded.
# Subtitles for video 6jXo8V6hWuQ already downloaded.
# Subtitles for video P2eX35KN_NE already downloaded.
# Subtitles for video 5ttCg2X0Mfc already downloaded.
# Subtitles for video iDptpZ0QUTQ already downloaded.
# Subtitles for video z6IgPEO2jAk already downloaded.
# Subtitles for video c16KNk4f9v4 already downloaded.
# Subtitles for video Wn244ffkc8I already downloaded.
# Checking channel: UCIaH-gZIVC432YRjNVvnyCA
# Subtitles for video i8glNTjOUW0 already downloaded.
# Subtitles for video vPA_C8V9fF0 already downloaded.
# Subtitles for video NkSXtukw1VA already downloaded.
# Subtitles for video zFDSR0Bs_4M already downloaded.
# Subtitles for video A5kOJAXeidM already downloaded.
# Subtitles for video _5w8rgFM5XY already downloaded.
# Subtitles for video E5Ajy3Ta8WY already downloaded.
# Subtitles for video Tdg1A9DHYbc already downloaded.
# Subtitles for video 4plsG4NxvqA already downloaded.
# Subtitles for video sYCJeY7qntY already downloaded.
# Subtitles for video -lDza7kSqvw already downloaded.
# Subtitles for video EL53Ar5gsoc already downloaded.
# Subtitles for video a1CJkfPleB4 already downloaded.
# Subtitles for video ApbK781zW64 already downloaded.
# Subtitles for video NpQegjmv6Cw already downloaded.
# Subtitles for video ZOD-C67bUc4 already downloaded.
# Subtitles for video vWsUqOxbrmM already downloaded.
# Subtitles for video _djQ4MFanCY already downloaded.
# Subtitles for video yLOVqYwhRxs already downloaded.
# Subtitles for video hDD3ZNUmEiQ already downloaded.
# Subtitles for video PxMLlgt1x-Q already downloaded.
# Subtitles for video VDaJHKuTBEI already downloaded.
# Subtitles for video EKDxZmu9Awc already downloaded.
# Subtitles for video rCNMwSM2kDU already downloaded.
# Subtitles for video 5b8uj7caRFk already downloaded.
# Subtitles for video aFiZeJNCivE already downloaded.
# Subtitles for video IuY4Kk1ssXY already downloaded.
# Subtitles for video eZUZkHxo_Jw already downloaded.
# Subtitles for video gO5Fm79GbBE already downloaded.
# Subtitles for video WeNChxMJJro already downloaded.
# Subtitles for video B7An4jA2Wec already downloaded.
# Subtitles for video SdY186NHKzI already downloaded.
# Subtitles for video lXQF8Dw0dYA already downloaded.
# Subtitles for video qvpw4_O25eU already downloaded.
# Subtitles for video IIcmtqHsD8g already downloaded.
# Subtitles for video qHBSQ12eIfA already downloaded.
# Subtitles for video RE4n29uEldA already downloaded.
# Subtitles for video Q8DVyLbGHzU already downloaded.
# Subtitles for video LYZzx6lSBVE already downloaded.
# Subtitles for video 18Lyja5BGy4 already downloaded.
# Subtitles for video v5oSIqqxLaA already downloaded.
# Subtitles for video iizxgmsnGT8 already downloaded.
# Subtitles for video kMkSYRqYej4 already downloaded.
# Subtitles for video w0uwP6Zy1VE already downloaded.
# Subtitles for video WKQlDn-KVmI already downloaded.
# Subtitles for video vR1BaN-7Yrk already downloaded.
# Subtitles for video bdw1MhEuSy0 already downloaded.
# Subtitles for video ni7xrQ6yisU already downloaded.
# Subtitles for video 4J2vt2jjra0 already downloaded.
# Subtitles for video BQHo-z-pA8E already downloaded.
# Checking channel: UCznv7Vf9nBdJYvBagFdAHWw
# Subtitles for video BnFzjcPTSsc already downloaded.
# Subtitles for video iyRAAMnaJqk already downloaded.
# Subtitles for video dOh0DqB04e0 already downloaded.
# Subtitles for video yhc1sM2NnQY already downloaded.
# Subtitles for video 0ZNVkINKbCo already downloaded.
# Subtitles for video jIBo69EsAzw already downloaded.
# Subtitles for video quIvyCFVCCk already downloaded.
# Subtitles for video 2bZSzObqAjE already downloaded.
# Subtitles for video BFMCySpcroI already downloaded.
# Subtitles for video kM4WtefjJZ8 already downloaded.
# Subtitles for video 8ixRrg7qNKY already downloaded.
# Subtitles for video OjEdoOFWYQQ already downloaded.
# Subtitles for video UXXi2op7xp8 already downloaded.
# Subtitles for video tMJKf7_lC4E already downloaded.
# Subtitles for video UhB1dpbobBk already downloaded.
# Subtitles for video -Fuuh7lyX-g already downloaded.
# Subtitles for video EGnDhd--BiM already downloaded.
# Subtitles for video I7AJA3o0jkY already downloaded.
# Subtitles for video dy6nRYTsKH4 already downloaded.
# Subtitles for video o96LNLaiDsc already downloaded.
# Subtitles for video h0aGN_rdnMQ already downloaded.
# Subtitles for video _BsTanbwZRE already downloaded.
# Subtitles for video L2aQx0Zb66Q already downloaded.
# Subtitles for video BIGjrNmLA8g already downloaded.
# Subtitles for video afTSoaIKwNs already downloaded.
# Subtitles for video Wia7EQPkuzU already downloaded.
# Subtitles for video Iq8iS5VsAHQ already downloaded.
# Subtitles for video 8w6HODIn1vc already downloaded.
# Subtitles for video OobjdM0mHcM already downloaded.
# Subtitles for video EX_iBWj5EPo already downloaded.
# Subtitles for video K9slJnQqN90 already downloaded.
# Subtitles for video 9Pstpq3a4uM already downloaded.
# Subtitles for video CHle8VRc3rg already downloaded.
# Subtitles for video FcXtrFbat2I already downloaded.
# Subtitles for video QoThEjfp4dQ already downloaded.
# Subtitles for video KoAa4qn6bps already downloaded.
# Subtitles for video v3Gav83TUUw already downloaded.
# Subtitles for video 9wskHTL9sX4 already downloaded.
# Subtitles for video PK2_VQj7ttE already downloaded.
# Subtitles for video TU9DkMxcXuo already downloaded.
# Subtitles for video OVJ3MwU1SFQ already downloaded.
# Subtitles for video x6-SfUw3elc already downloaded.
# Subtitles for video P-8a0lZd4H4 already downloaded.
# Subtitles for video IrvrHoLtal8 already downloaded.
# Subtitles for video _tBrxckIwJw already downloaded.
# Subtitles for video CDhjVlCZDMs already downloaded.
# Subtitles for video Ieu68CfTR4g already downloaded.
# Subtitles for video EaDKhFqBr_c already downloaded.
# Subtitles for video j8WCRFct0qU already downloaded.
# Subtitles for video vqHpx0eAIiY already downloaded.
# Checking channel: UCUyDOdBWhC1MCxEjC46d-zw
# Subtitles for video 6OQfobJGe0Y already downloaded.
# Subtitles for video iDHLRoB-mvQ already downloaded.
# Subtitles for video fp9REQFC2g8 already downloaded.
# Subtitles for video dy1Xlo4c-KA already downloaded.
# Subtitles for video HwPXctiw_rY already downloaded.
# Subtitles for video -HWa1hHGAt0 already downloaded.
# Subtitles for video fC6T4Ca60oM already downloaded.
# Subtitles for video kIW1CTBzu5s already downloaded.
# Subtitles for video pXjO-6DIYBU already downloaded.
# Subtitles for video MHILW3eMmfQ already downloaded.
# Subtitles for video JORS29FKfgs already downloaded.
# Subtitles for video s4ZAaNimVLQ already downloaded.
# Subtitles for video -Oih_QxPW4Q already downloaded.
# Subtitles for video XS1Bqw60VPw already downloaded.
# Subtitles for video jOSPJmSFTQs already downloaded.
# Subtitles for video v27GrNh7VTA already downloaded.
# Subtitles for video _AZVkJBkxvw already downloaded.
# Subtitles for video CENGRXQd1Yo already downloaded.
# Subtitles for video J4rUw-45QMs already downloaded.
# Subtitles for video ZS8Zo-dBiz8 already downloaded.
# Subtitles for video d29yQlxH4LA already downloaded.
# Subtitles for video QwEb78e5a8Y already downloaded.
# Subtitles for video PAYkFA-RF4s already downloaded.
# Subtitles for video VZmCS9TYUgo already downloaded.
# Subtitles for video vM22czeEVl4 already downloaded.
# Subtitles for video OLwKAIRYd_w already downloaded.
# Subtitles for video v1rQL1-Ywg8 already downloaded.
# Subtitles for video k4oeH840ouw already downloaded.
# Subtitles for video y14UX7Fp-Ow already downloaded.
# Subtitles for video 1uRZilaI_O0 already downloaded.
# Subtitles for video Kvgwgu7ceHM already downloaded.
# Subtitles for video _9yrNW4GpUc already downloaded.
# Subtitles for video OXleZ-BaEO0 already downloaded.
# Subtitles for video npi7UeOE_0o already downloaded.
# Subtitles for video 6QJmeqzxTLw already downloaded.
# Subtitles for video sBJppqCeFGI already downloaded.
# Subtitles for video rT5TALmnjJI already downloaded.
# Subtitles for video t3YXp4KVAwc already downloaded.
# Subtitles for video b4mUR8KreCg already downloaded.
# Subtitles for video qrmm6RaZyI4 already downloaded.
# Subtitles for video OP0u_lSkXR0 already downloaded.
# Subtitles for video mjZhNn9_owk already downloaded.
# Subtitles for video AX3oidjc5Cs already downloaded.
# Subtitles for video 0UTkT4mwaTs already downloaded.
# Subtitles for video i1TuDe4i4MU already downloaded.
# Subtitles for video SdXffC1oHBs already downloaded.
# Subtitles for video 8tojm5FnA-8 already downloaded.
# Subtitles for video Mft3DFYa0_I already downloaded.
# Subtitles for video eX3Ch_HuR70 already downloaded.
# Subtitles for video bHrnwVhFpcc already downloaded.
# Checking channel: UC1E1SVcVyU3ntWMSQEp38Yw
# Subtitles for video ru2TbIivEkA already downloaded.
# Subtitles for video ibewGFp6qk0 already downloaded.
# Subtitles for video ftw4upUmc9o already downloaded.
# Subtitles for video gkXzhwWDZy8 already downloaded.
# Subtitles for video t7mBPUZlBD4 already downloaded.
# Subtitles for video hea28O6xoJ4 already downloaded.
# Subtitles for video 6mGn5uxoIFU already downloaded.
# Subtitles for video P1Ka_KjM12g already downloaded.
# Subtitles for video CYeLpE3lFCk already downloaded.
# Subtitles for video T_5zHExXN7o already downloaded.
# Subtitles for video ugrvTYidJk4 already downloaded.
# Subtitles for video 5d-Lncy9ypU already downloaded.
# Subtitles for video G8Cl4Tg0_7A already downloaded.
# Subtitles for video 6-id91XTcuQ already downloaded.
# Subtitles for video RHyYN2-_kK0 already downloaded.
# Subtitles for video 239wkAt_AvY already downloaded.
# Subtitles for video ezgnwL_L2c8 already downloaded.
# Subtitles for video ZO08wFqMGXQ already downloaded.
# Subtitles for video -9pSxUocYk4 already downloaded.
# Subtitles for video 83KiCqzTtag already downloaded.
# Subtitles for video HNTRc_HufEo already downloaded.
# Subtitles for video VCXlnCOnMfk already downloaded.
# Subtitles for video ZCkyQUy-jtQ already downloaded.
# Subtitles for video Cd_YlDyWghg already downloaded.
# Subtitles for video z6K1unREOhQ already downloaded.
# Subtitles for video S4Q0CKU_VGU already downloaded.
# Subtitles for video o8tBgVrCMhc already downloaded.
# Subtitles for video Kgw8AMRaLIw already downloaded.
# Subtitles for video 1xDeBTXA4b0 already downloaded.
# Subtitles for video Cfgk9kEgmqM already downloaded.
# Subtitles for video Ku5oLSw7tCM already downloaded.
# Subtitles for video A7fv3kkSOFk already downloaded.
# Subtitles for video cheX5qL_B8s already downloaded.
# Subtitles for video L9ypZEoWdw8 already downloaded.
# Subtitles for video YsnDQJUZ-Xs already downloaded.
# Subtitles for video FCKP_LZKPI8 already downloaded.
# Subtitles for video Ov_ZZlH30gk already downloaded.
# Subtitles for video OPbRKadjq8g already downloaded.
# Subtitles for video a_KjxZ5SnhI already downloaded.
# Subtitles for video XkvJ8Nr0zzA already downloaded.
# Subtitles for video EHIa6EvsNLw already downloaded.
# Subtitles for video Q6B2ceRNKL8 already downloaded.
# Subtitles for video yxT8HFc1TNM already downloaded.
# Subtitles for video zoQAEem0rOo already downloaded.
# Subtitles for video kNgTx2xCxSw already downloaded.
# Subtitles for video JyxH21ek7jU already downloaded.
# Subtitles for video PcW2F-DqbqU already downloaded.
# Subtitles for video ug7RRgPAS7Y already downloaded.
# Subtitles for video wo2LTuG3ZuI already downloaded.
# Subtitles for video xfiM9cy0V2Q already downloaded.
# Checking channel: UCdMrj5kezVrTiqZoFRqGxAg
# Subtitles for video 0N5x5ssuSsQ already downloaded.
# Subtitles for video L5-Q6vL6Ok4 already downloaded.
# Subtitles for video gQJsCzUWwkI already downloaded.
# Subtitles for video Qzu5bgJofdI already downloaded.
# Subtitles for video 6vxr9MfXBEc already downloaded.
# Subtitles for video zFXIiLt5L9Q already downloaded.
# Subtitles for video tzFOXGLV93M already downloaded.
# Subtitles for video Ww3w4co7d2A already downloaded.
# Subtitles for video yowhTo8oXz0 already downloaded.
# Subtitles for video EtgquVexj2o already downloaded.
# Subtitles for video fKUETJ9bETw already downloaded.
# Subtitles for video cQJ-60ctPBA already downloaded.
# Subtitles for video -IzMETPko4Y already downloaded.
# Subtitles for video 4KS0frYusjk already downloaded.
# Subtitles for video FAKgPz9caaw already downloaded.
# Subtitles for video p3Lg-Ka6MhI already downloaded.
# Subtitles for video QKV7msvEv0E already downloaded.
# Subtitles for video -Y3nBd1jhmo already downloaded.
# Subtitles for video dOfHhaLI9aE already downloaded.
# Subtitles for video 0JfRPXYFQHE already downloaded.
# Subtitles for video EXMTbeCM-9Y already downloaded.
# Subtitles for video 8oCYbliC6go already downloaded.
# Subtitles for video ZGRLZSAyekY already downloaded.
# Subtitles for video 9KwYZqN2EIc already downloaded.
# Subtitles for video SYvDw3d60aU already downloaded.
# Subtitles for video I8dJ111nHaE already downloaded.
# Subtitles for video IQ20dby8ujY already downloaded.
# Subtitles for video eR2coEfoAoM already downloaded.
# Subtitles for video QXLzOLp6bXs already downloaded.
# Subtitles for video dwscDrsbsjw already downloaded.
# Subtitles for video 1kHUsdRGcNM already downloaded.
# Subtitles for video 3-YS7UJ8KDI already downloaded.
# Subtitles for video 2mMiVBmGxnY already downloaded.
# Subtitles for video x1tRGiFODag already downloaded.
# Subtitles for video EcwjxiXNAGU already downloaded.
# Subtitles for video bFPgxGR4MMU already downloaded.
# Subtitles for video kJSGh69DAl8 already downloaded.
# Subtitles for video i_4g5CzAoHE already downloaded.
# Subtitles for video A7NMgAG8RJA already downloaded.
# Subtitles for video 3LI_GW7SjcI already downloaded.
# Subtitles for video VvBNAKidqrs already downloaded.
# Subtitles for video TzilqW4WbAE already downloaded.
# Subtitles for video PZmSIuh1VV4 already downloaded.
# Subtitles for video FUlKbgmOa9M already downloaded.
# Subtitles for video PAu98nxQpWE already downloaded.
# Subtitles for video N1LH6XixCao already downloaded.
# Subtitles for video UzCp9hMOs_I already downloaded.
# Subtitles for video PYPocXDWyVM already downloaded.
# Subtitles for video 6j5WdPC8Xck already downloaded.
# Subtitles for video xJK90xjJ7pM already downloaded.
# Checking channel: UCQ-rrUCsJLNjFdPtKq0YOfA
# Subtitles for video Jgh6xFoeuVc already downloaded.
# Subtitles for video X1IDehzSNoU already downloaded.
# Subtitles for video rDAbo1Gqujg already downloaded.
# Subtitles for video tLZgU4vbQLE already downloaded.
# Subtitles for video 3pY0KWwVAV4 already downloaded.
# Subtitles for video PwyAnL1uZKA already downloaded.
# Subtitles for video qTLehviusSs already downloaded.
# Subtitles for video txzX11Zf_ZA already downloaded.
# Subtitles for video 6XYIo7-Scb8 already downloaded.
# Subtitles for video fO64lPhHMa0 already downloaded.
# Subtitles for video c9Crn_o5DW0 already downloaded.
# Subtitles for video 2hSdEkDe87s already downloaded.
# Subtitles for video seMvuxRct1Q already downloaded.
# Subtitles for video vU3JqUt8Hhc already downloaded.
# Subtitles for video 6y5t4TIQJJg already downloaded.
# Subtitles for video 4Y3-86dXpg4 already downloaded.
# Subtitles for video EHvASCrRtd4 already downloaded.
# Subtitles for video 8TnhiapOfpE already downloaded.
# Subtitles for video CslLl1fVK8U already downloaded.
# Subtitles for video PLWjOO_1SSU already downloaded.
# Subtitles for video FDuAfkR6bck already downloaded.
# Subtitles for video 0eS7Z5te4EU already downloaded.
# Subtitles for video SqMI-RugFk0 already downloaded.
# Subtitles for video BWoRH5AtYF0 already downloaded.
# Subtitles for video QNP0QqLThyI already downloaded.
# Subtitles for video ieuPEgGMS2w already downloaded.
# Subtitles for video tL71OzGcewk already downloaded.
# Subtitles for video nVWnDft6KW0 already downloaded.
# Subtitles for video WAmczA-JjGY already downloaded.
# Subtitles for video 8MLvzAhKjlM already downloaded.
# Subtitles for video k72aCBm7Jpk already downloaded.
# Subtitles for video Mf8MZ8Iy8sE already downloaded.
# Subtitles for video cdVeSJHewDM already downloaded.
# Subtitles for video Wfwyk1TK1Aw already downloaded.
# Subtitles for video Hc3u0bUu8eg already downloaded.
# Subtitles for video X1xSXDDzlcM already downloaded.
# Subtitles for video cT0Fo3rYJI4 already downloaded.
# Subtitles for video Z_SbuCOAOqQ already downloaded.
# Subtitles for video d6AEeD4rQBA already downloaded.
# Subtitles for video Qb5D22pXjKE already downloaded.
# Subtitles for video BrkJsLFtGyg already downloaded.
# Subtitles for video q4Mfqt6F1Nk already downloaded.
# Subtitles for video 26akKrNC_pk already downloaded.
# Subtitles for video ZaPyk33pRM0 already downloaded.
# Subtitles for video v6kails_NUk already downloaded.
# Subtitles for video -GlgArhTGbQ already downloaded.
# Subtitles for video 4tlJIeM05_s already downloaded.
# Subtitles for video 798LBCW-u2M already downloaded.
# Subtitles for video EGTB5FgXPeU already downloaded.
# Subtitles for video 9cx7trtr98E already downloaded.
# Checking channel: UCyaN6mg5u8Cjy2ZI4ikWaug
# Subtitles for video DWgQk1AFCbE already downloaded.
# Subtitles for video JYVGcAYNyjg already downloaded.
# Subtitles for video mi_ruY-xIks already downloaded.
# Subtitles for video x4uNezl50lk already downloaded.
# Subtitles for video ezFDXJv-baA already downloaded.
# Subtitles for video 8mfCfVvZmFM already downloaded.
# Subtitles for video 3q1QvEkbbyk already downloaded.
# Subtitles for video TRYykS7Ts3k already downloaded.
# Subtitles for video 7_7wNEl98cM already downloaded.
# Subtitles for video nhIm0Zv-EZw already downloaded.
# Subtitles for video uT97Qea5BiU already downloaded.
# Subtitles for video 3Mz-LVJP4Qk already downloaded.
# Subtitles for video b2t9NZwJz-o already downloaded.
# Subtitles for video XPAc_kGDgEY already downloaded.
# Subtitles for video eFKLymJpZS8 already downloaded.
# Subtitles for video c95x2l4pFVQ already downloaded.
# Subtitles for video WCpXuEVYBBc already downloaded.
# Subtitles for video lF9CNiM4GBo already downloaded.
# Subtitles for video eQF1oLwdWcM already downloaded.
# Subtitles for video 4pHcxoZ0j9A already downloaded.
# Subtitles for video A_49yd1aojk already downloaded.
# Subtitles for video onaLfllSBvw already downloaded.
# Subtitles for video Ft7-02vmmM4 already downloaded.
# Subtitles for video 1WPX3WnXMxw already downloaded.
# Subtitles for video oW7obR9di0M already downloaded.
# Subtitles for video QMInAfhIuTQ already downloaded.
# Subtitles for video WghA0k94wd8 already downloaded.
# Subtitles for video siS5sTZZnOA already downloaded.
# Subtitles for video Wn881oyNH0U already downloaded.
# Subtitles for video AoqqK7L0Bvc already downloaded.
# Subtitles for video -HfUCbnapKo already downloaded.
# Subtitles for video qkcFcwb6mk0 already downloaded.
# Subtitles for video 6EAXOsfWc8Q already downloaded.
# Subtitles for video s4sM7qS0YaE already downloaded.
# Subtitles for video QhBVi-sQQKc already downloaded.
# Subtitles for video KOhBfczTmLg already downloaded.
# Subtitles for video 1o4tLOiOxgU already downloaded.
# Subtitles for video OZbcrfWfqZc already downloaded.
# Subtitles for video Hsw_ku6YlCA already downloaded.
# Subtitles for video 4fxsfkHbEBM already downloaded.
# Subtitles for video sDf6UO6W_Ps already downloaded.
# Subtitles for video Cy7yWYzqguM already downloaded.
# Subtitles for video mWvO-leftAo already downloaded.
# Subtitles for video syDpQtORBzg already downloaded.
# Subtitles for video TOQtJch3kGk already downloaded.
# Subtitles for video rjAtM_ZPQ9c already downloaded.
# Subtitles for video Ig5EyRZMoQw already downloaded.
# Subtitles for video NXuJQqNzI00 already downloaded.
# Subtitles for video vmiTsebSp60 already downloaded.
# Subtitles for video N9UpuFPTk_I already downloaded.
# Checking channel: UCoigWuTGrLwnMwBep-LUqsA
# Subtitles for video czCVz7vhudA already downloaded.
# Subtitles for video p_JaRjfcSiE already downloaded.
# Subtitles for video UYHCoV-JGIQ already downloaded.
# Subtitles for video 6dWiglv590U already downloaded.
# Subtitles for video 4qNqByXGCBk already downloaded.
# Subtitles for video ODd7YW3_F54 already downloaded.
# Subtitles for video yFId71rp4Nc already downloaded.
# Subtitles for video Jwr8GFYaZ3s already downloaded.
# Subtitles for video PgkUicrD-GU already downloaded.
# Subtitles for video DNV6P9ppe6s already downloaded.
# Subtitles for video ljtbB3yKYxo already downloaded.
# Subtitles for video t8SRBHtEeXA already downloaded.
# Subtitles for video 8zYXZ8TZImA already downloaded.
# Subtitles for video OcPwIguzz1k already downloaded.
# Subtitles for video 6wWp7CfSu7Y already downloaded.
# Subtitles for video HJLViK8VJds already downloaded.
# Subtitles for video pL3_7s_dokE already downloaded.
# Subtitles for video epvuTGkApRU already downloaded.
# Subtitles for video e8m8QdqudJU already downloaded.
# Subtitles for video 5C9N_N4PqpA already downloaded.
# Subtitles for video yTFC3TbiW-Q already downloaded.
# Subtitles for video cj0-Bd4uQqs already downloaded.
# Subtitles for video MwBdOAN1vC8 already downloaded.
# Subtitles for video GOsAI71TKiI already downloaded.
# Subtitles for video W1VJr5Fkbts already downloaded.
# Subtitles for video hSzQujoVTPM already downloaded.
# Subtitles for video FOQFsI8l3QA already downloaded.
# Subtitles for video PDSRg_Rrd7M already downloaded.
# Subtitles for video zY-CGPLlwWI already downloaded.
# Subtitles for video vzhmyINvK3k already downloaded.
# Subtitles for video GL0xwd8MLO0 already downloaded.
# Subtitles for video dQVEQSUrUfw already downloaded.
# Subtitles for video aXSHMQ3vqok already downloaded.
# Subtitles for video Ah__9Q-C2to already downloaded.
# Subtitles for video cjhy5Hbd0nc already downloaded.
# Subtitles for video NBom64vyIfo already downloaded.
# Subtitles for video 5cFZpMnDJ2M already downloaded.
# Subtitles for video 7LeUslLWWUk already downloaded.
# Subtitles for video ugWDCJhKFxw already downloaded.
# Subtitles for video s3NQluHtrj0 already downloaded.
# Subtitles for video x1sFIx0k4lI already downloaded.
# Subtitles for video DDwB5AZQgyo already downloaded.
# Subtitles for video 1Lxjkb9iT-M already downloaded.
# Subtitles for video Y4BY6QnTQu0 already downloaded.
# Subtitles for video vRR7d6AA_hg already downloaded.
# Subtitles for video eENmmkVbsXg already downloaded.
# Checking channel: UCyFqFYfTW2VoIQKylJ04Rtw
# Subtitles for video uSchEDY6y20 already downloaded.
# Subtitles for video YhqIO6lAzi8 already downloaded.
# Subtitles for video mIU0VS5KkeE already downloaded.
# Subtitles for video wQ-KRhCOHS4 already downloaded.
# Subtitles for video 6gwIDBjcYGk already downloaded.
# Subtitles for video d5qG1Vo3Qvc already downloaded.
# Subtitles for video nUKLhaa0Pus already downloaded.
# Subtitles for video tvRj_PyQL-g already downloaded.
# Subtitles for video K5qDnLxr4N4 already downloaded.
# Subtitles for video MooL0NF9xY8 already downloaded.
# Subtitles for video 0sbZ-rjrwBk already downloaded.
# Subtitles for video 4VG9B05xD7M already downloaded.
# Subtitles for video yZGITiFFAEc already downloaded.
# Subtitles for video EdUktbZh-BQ already downloaded.
# Subtitles for video jBMcnLVHS9c already downloaded.
# Subtitles for video 892_Bd5dX7o already downloaded.
# Subtitles for video 6AaYxiuujx0 already downloaded.
# Subtitles for video itBBseVtA6g already downloaded.
# Subtitles for video 18U8T5KKedg already downloaded.
# Subtitles for video 6FEPo27-ywM already downloaded.
# Subtitles for video n8qBow5Elac already downloaded.
# Subtitles for video pz-EByM0RtM already downloaded.
# Subtitles for video PInEkBW03qY already downloaded.
# Subtitles for video XFfzKO_VB-k already downloaded.
# Subtitles for video fqQ5IMGRAzk already downloaded.
# Subtitles for video B11ZjZ4O_vI already downloaded.
# Subtitles for video dh6O9WJrCtE already downloaded.
# Subtitles for video _3GC37EpxSE already downloaded.
# Subtitles for video FZItbr4ZJnc already downloaded.
# Subtitles for video 98LEVsmcNr4 already downloaded.
# Subtitles for video EEYYHeOTwEo already downloaded.
# Subtitles for video akE-HH45qjQ already downloaded.
# Subtitles for video JBRH8z9pk0E already downloaded.
# Subtitles for video yJPYmLDnBjA already downloaded.
# Subtitles for video tuB3_fJyC5Q already downloaded.
# Subtitles for video 9H9obz-5P24 already downloaded.
# Subtitles for video oAyYILh0ULU already downloaded.
# Subtitles for video ednjcmvdf9Q already downloaded.
# Subtitles for video qqutPUcqhpA already downloaded.
# Subtitles for video rkKHqQ6RMJY already downloaded.
# Subtitles for video 8fCgGQ9fjPE already downloaded.
# Subtitles for video IJUCnx7qhe4 already downloaded.
# Subtitles for video 4tQz4pB9bZw already downloaded.
# Subtitles for video duGsS1ptrNM already downloaded.
# Subtitles for video stx1NxvopXw already downloaded.
# Subtitles for video R4HptzNSPFc already downloaded.
# Subtitles for video XiJpR5H0WT0 already downloaded.
# Subtitles for video PjNkXqW3W4w already downloaded.
# Subtitles for video M0CrD-WWLTE already downloaded.
# Subtitles for video 7bqx_EbRoVU already downloaded.
# Checking channel: UC2D2CMWXMOVWx7giW1n3LIg
# Subtitles for video Nmo4bxfFzM0 already downloaded.
# Subtitles for video p6zNt7HUCrY already downloaded.
# Subtitles for video KuuoLT-fq4s already downloaded.
# Subtitles for video Vh97z1ephuc already downloaded.
# Subtitles for video goCbY3zIZKo already downloaded.
# Subtitles for video c9JmHOUp6VU already downloaded.
# Subtitles for video Ag_a3VAQlgk already downloaded.
# Subtitles for video N5DAW8mkJ6Y already downloaded.
# Subtitles for video rkFHdXo1O0w already downloaded.
# Subtitles for video v4HRWgwjP_k already downloaded.
# Subtitles for video bAWUYuygS_U already downloaded.
# Subtitles for video FCFQx3cA0Lg already downloaded.
# Subtitles for video Z3OpxT65fKw already downloaded.
# Subtitles for video qdk7XuBgSjw already downloaded.
# Subtitles for video QYAgf_lfio4 already downloaded.
# Subtitles for video _2u_FiHTuvQ already downloaded.
# Subtitles for video OLQRAMZi--c already downloaded.
# Subtitles for video wAnDWfEIwoE already downloaded.
# Subtitles for video Q4qWzbP0q7I already downloaded.
# Subtitles for video 8tkQDgUdpLs already downloaded.
# Subtitles for video Kyud5aFGjHU already downloaded.
# Subtitles for video 3-ukCGQJk2c already downloaded.
# Subtitles for video Uv-O7SZQ1H4 already downloaded.
# Subtitles for video qUz93CyNIz0 already downloaded.
# Subtitles for video qi4VwpEs3LE already downloaded.
# Subtitles for video 7aj00T-TKDc already downloaded.
# Subtitles for video SjPJn4QP0dk already downloaded.
# Subtitles for video 2PgNi03lLc0 already downloaded.
# Subtitles for video 5Gg_uZIumtE already downloaded.
# Subtitles for video J2oqi41dCNc already downloaded.
# Subtitles for video D97TQuy946k already downloaded.
# Subtitles for video yRSBl2ovMz4 already downloaded.
# Subtitles for video K0hkhbGYaGQ already downloaded.
# Subtitles for video nyxlCNcvaLA already downloaded.
# Subtitles for video jwChiek_aRY already downloaded.
# Subtitles for video Phm-Alz1Zjo already downloaded.
# Subtitles for video 4AwyVTHEU3s already downloaded.
# Subtitles for video 6YLdlK2hYnw already downloaded.
# Subtitles for video tR73Ny4Dt9s already downloaded.
# Subtitles for video hF32FvBH4gI already downloaded.
# Subtitles for video 8N7mdkrXgbc already downloaded.
# Subtitles for video JnlSDaBjCCU already downloaded.
# Subtitles for video In9Bq4EJMZw already downloaded.
# Subtitles for video 1SXDXdngX2M already downloaded.
# Subtitles for video z5W74QC3v2I already downloaded.
# Subtitles for video q-H_A_dQUxQ already downloaded.
# Subtitles for video 6RZbGrq9BxE already downloaded.
# Subtitles for video Og56hmAspV8 already downloaded.
# Subtitles for video lIo9FcrljDk already downloaded.
# Subtitles for video etbfLTHD_VU already downloaded.
# Checking channel: UCiHQaw8jIdtPL0PM1ksyLoQ
# Subtitles for video xvLzpsj3EmY already downloaded.
# Subtitles for video 9rWVyklmAx0 already downloaded.
# Subtitles for video 8_ZRZccKmvg already downloaded.
# Subtitles for video 3SNP_s_Lb50 already downloaded.
# Subtitles for video iBlfMj4xDrk already downloaded.
# Subtitles for video cutwajo2swc already downloaded.
# Subtitles for video cqf-7OyT6h0 already downloaded.
# Subtitles for video WT49zrb5Rpk already downloaded.
# Subtitles for video gIMc18OvLZs already downloaded.
# Subtitles for video DBSfV55BxGg already downloaded.
# Subtitles for video BDGdeiqiRcE already downloaded.
# Subtitles for video aqrj1pVi_HQ already downloaded.
# Subtitles for video D21smRTpvDY already downloaded.
# Subtitles for video KrQRcoVS_TA already downloaded.
# Subtitles for video fwAhR8frRyA already downloaded.
# Subtitles for video MMTaEfZ3bjw already downloaded.
# Subtitles for video 4IXUWSZb7wM already downloaded.
# Subtitles for video E6C-P63152g already downloaded.
# Subtitles for video SIfx-Zu9xM4 already downloaded.
# Subtitles for video _Ql4QqMGG98 already downloaded.
# Subtitles for video Zwzjz-FaQOs already downloaded.
# Subtitles for video NOvIiiPcZ0c already downloaded.
# Subtitles for video G8p0vK7nubM already downloaded.
# Subtitles for video tXrBt-HrAPA already downloaded.
# Subtitles for video 8IRi_HsXdVk already downloaded.
# Subtitles for video tJvvLorw3LQ already downloaded.
# Subtitles for video PyPntS7MZYY already downloaded.
# Subtitles for video 8OtEfmaeS5Y already downloaded.
# Subtitles for video ES77RjHKwR0 already downloaded.
# Subtitles for video mT59yNVoBJc already downloaded.
# Subtitles for video kiuwkXPw3xw already downloaded.
# Subtitles for video ZOMNr1RoyMc already downloaded.
# Subtitles for video To5P_mna1tk already downloaded.
# Subtitles for video 0ZJOaFFFwn0 already downloaded.
# Subtitles for video kRU2SZvvMGk already downloaded.
# Subtitles for video dZTA_HUUjEk already downloaded.
# Subtitles for video sHPZfYtyCZ0 already downloaded.
# Subtitles for video UbgvMvEmK3k already downloaded.
# Subtitles for video X9RX7MyPY1w already downloaded.
# Subtitles for video y4WaOzgBnD8 already downloaded.
# Subtitles for video 2q9j1waKXeA already downloaded.
# Subtitles for video f_pwzw601-k already downloaded.
# Subtitles for video aDCEzm2gUiM already downloaded.
# Subtitles for video Q413xh761uU already downloaded.
# Subtitles for video ROZ6lHaN8X0 already downloaded.
# Subtitles for video F58RYesGiUU already downloaded.
# Subtitles for video W08aS5_IeiI already downloaded.
# Subtitles for video zG4IkE0BFdQ already downloaded.
# Subtitles for video S9EE-ltJid0 already downloaded.
# Subtitles for video Sw8LuZt7mYY already downloaded.
# Checking channel: UCRQlx2klE_aNrPhz2OyKRdg
# Subtitles for video U_1gTvtICHU already downloaded.
# Subtitles for video ENCan-AKv_0 already downloaded.
# Subtitles for video aVX8tAFshDM already downloaded.
# Subtitles for video UqJi-L2xuz8 already downloaded.
# Subtitles for video BJK-A1jgnrU already downloaded.
# Subtitles for video lIMsnmbtc68 already downloaded.
# Subtitles for video JudB76WQiKk already downloaded.
# Subtitles for video J5lPAj5uG-g already downloaded.
# Subtitles for video -G5kizblSng already downloaded.
# Subtitles for video FFdmok7k-y8 already downloaded.
# Subtitles for video Gev6xX_Zhmg already downloaded.
# Subtitles for video C4REPv7rb_g already downloaded.
# Subtitles for video 7dx5pdS_UCU already downloaded.
# Subtitles for video UYkId4xvsjI already downloaded.
# Subtitles for video pLUfKOf4q4Q already downloaded.
# Subtitles for video bP6UE31pvVA already downloaded.
# Subtitles for video uDymQEdx9lw already downloaded.
# Subtitles for video 8Rtfsjwu5ts already downloaded.
# Subtitles for video yLiBIqsw_Sk already downloaded.
# Subtitles for video Ne-AAFQl49k already downloaded.
# Subtitles for video 9rZSLkGN640 already downloaded.
# Subtitles for video XqtroBnlSjo already downloaded.
# Subtitles for video nUAynY-WmPI already downloaded.
# Subtitles for video lKukL6RgsDo already downloaded.
# Subtitles for video 7PPPlsDBEqE already downloaded.
# Subtitles for video CeVegkWa1gc already downloaded.
# Subtitles for video XsJjhYxxTPo already downloaded.
# Subtitles for video fxc75ZdFFc4 already downloaded.
# Subtitles for video AKOpzefZrPA already downloaded.
# Subtitles for video J9TtkZTzZ0A already downloaded.
# Subtitles for video gc8VstbuOQA already downloaded.
# Fetching subtitles for video: Codie Sanchez on How to Become a Main Street Millionaire: The Secrets to Profiting from &#39;Boring&#39; ... (rXAyzrDSopk)
# No subtitles available for video rXAyzrDSopk:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=rXAyzrDSopk! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Subtitles for video vhhB6hrkOMU already downloaded.
# Subtitles for video bJoxEhykRFA already downloaded.
# Subtitles for video W56NmeyIMQs already downloaded.
# Subtitles for video z3f-GldjO8o already downloaded.
# Subtitles for video EbB1lQ3UGpI already downloaded.
# Subtitles for video XaB5SK_-4e4 already downloaded.
# Subtitles for video S0h2uaxhDc8 already downloaded.
# Subtitles for video RUHUcxwbnN8 already downloaded.
# Subtitles for video _GgQ03qPIVI already downloaded.
# Subtitles for video xj0K35AWwg0 already downloaded.
# Subtitles for video m7Sqy7UR4o0 already downloaded.
# Subtitles for video i_mjEV7hH38 already downloaded.
# Subtitles for video WvxmBl5eza4 already downloaded.
# Subtitles for video e5cGTvCRvWE already downloaded.
# Subtitles for video vGFnBfuPqzU already downloaded.
# Subtitles for video A_LIvPvHW4E already downloaded.
# Subtitles for video mZ2shHk_yPk already downloaded.
# Subtitles for video vNHvvnRxg80 already downloaded.
# Checking channel: UCd0n53aFGZoXxiz_sH74O4A
# Subtitles for video WecA4vr3KuI already downloaded.
# Subtitles for video P45h1M9vgSg already downloaded.
# Subtitles for video awNI093e6tQ already downloaded.
# Subtitles for video JIfxKPWwfPA already downloaded.
# Subtitles for video dZRqsUFr98c already downloaded.
# Subtitles for video ufn7TuRwttY already downloaded.
# Subtitles for video tX1pMl5UbRI already downloaded.
# Subtitles for video HI4CFwgBZkk already downloaded.
# Subtitles for video mLIwiW1g2a8 already downloaded.
# Subtitles for video TV_K9yymWds already downloaded.
# Subtitles for video pU1tyuWf8kE already downloaded.
# Subtitles for video eDpziCCeUTI already downloaded.
# Subtitles for video lQY2tMVqAVQ already downloaded.
# Subtitles for video t7zwFDbvqow already downloaded.
# Subtitles for video WRx6wDiOmWc already downloaded.
# Subtitles for video lItdZZHRtJ0 already downloaded.
# Subtitles for video 26k2xheqcic already downloaded.
# Subtitles for video Hec3jZICsSE already downloaded.
# Subtitles for video gJfpmJl74GE already downloaded.
# Subtitles for video tg9xzSoCsK0 already downloaded.
# Subtitles for video RmwXwqGzgdo already downloaded.
# Subtitles for video bMlQmiIeF6Y already downloaded.
# Subtitles for video WJzb69p4Kbw already downloaded.
# Subtitles for video 7ZIaVEK66Ic already downloaded.
# Subtitles for video 6FpSQtbvU74 already downloaded.
# Subtitles for video I-Crg7V5hBQ already downloaded.
# Subtitles for video oM6SGoQ4VDk already downloaded.
# Subtitles for video Ifv1ml8o2eo already downloaded.
# Subtitles for video m0kxds_WYDo already downloaded.
# Subtitles for video P5NtLc1GIo8 already downloaded.
# Subtitles for video UlwDrw7rVkM already downloaded.
# Subtitles for video k02k0HNtnrg already downloaded.
# Subtitles for video bgM9eQ6WTKo already downloaded.
# Subtitles for video Zmu24BRZlMU already downloaded.
# Subtitles for video b5Uos7SUnfw already downloaded.
# Subtitles for video _N77xSFq3bg already downloaded.
# Subtitles for video 0Zt6n4bw0ds already downloaded.
# Subtitles for video dODlo__g38I already downloaded.
# Subtitles for video hdVlMBvNY1U already downloaded.
# Subtitles for video FeueWQ6zy8I already downloaded.
# Subtitles for video Hz8KOxXTZ9M already downloaded.
# Subtitles for video mrtzACqLRss already downloaded.
# Subtitles for video mNO-66XqS40 already downloaded.
# Subtitles for video rgqrfL5a-c8 already downloaded.
# Subtitles for video 3WkXWVIjOEg already downloaded.
# Subtitles for video 23sBCxfXW1s already downloaded.
# Subtitles for video OclW8SBERLE already downloaded.
# Subtitles for video VSBOlSyt2-U already downloaded.
# Subtitles for video JIZMpRCaVJQ already downloaded.
# Subtitles for video 7yvt07-GIW4 already downloaded.
# Checking channel: UC60gRMJRjTuTskBnl-LkPAg
# Subtitles for video DKWXReQa-TU already downloaded.
# Subtitles for video x5jB3_gevfU already downloaded.
# Subtitles for video 42FIAuQcwLk already downloaded.
# Subtitles for video kzFCeExfoMw already downloaded.
# Subtitles for video 5bREMlWuwXk already downloaded.
# Subtitles for video lSfUxhXVe5Y already downloaded.
# Subtitles for video Ey3Uu0yHn2g already downloaded.
# Subtitles for video yqlQSDuDNQ4 already downloaded.
# Subtitles for video ySnV_WcsgoY already downloaded.
# Subtitles for video JjydTid3aCM already downloaded.
# Subtitles for video CRHwkI9rH5k already downloaded.
# Subtitles for video 5aCGLbp_8kM already downloaded.
# Subtitles for video aOWG1xTgTqo already downloaded.
# Subtitles for video S-g3zy9G-v4 already downloaded.
# Subtitles for video DB57CxyIOUI already downloaded.
# Subtitles for video myOLmm3IDsY already downloaded.
# Subtitles for video zgBM8ajA4uY already downloaded.
# Subtitles for video SUGzovQWVQU already downloaded.
# Subtitles for video X6Y4lgAY9yY already downloaded.
# Subtitles for video 34EV5HylKxg already downloaded.
# Subtitles for video JUFwlBehv4c already downloaded.
# Subtitles for video jmrSIKJ1XL8 already downloaded.
# Subtitles for video UJ4Aa95TMkE already downloaded.
# Subtitles for video _c5c01qWB-w already downloaded.
# Subtitles for video 0_GeW7g6N70 already downloaded.
# Subtitles for video dNHxohu409o already downloaded.
# Subtitles for video 3PQA9iTYCA8 already downloaded.
# Subtitles for video jlMvZ2N37vA already downloaded.
# Subtitles for video DPArkB5nGPc already downloaded.
# Subtitles for video tyn2yRK0X8A already downloaded.
# Subtitles for video tpJafRemQ2Q already downloaded.
# Subtitles for video uoAmpafRo5M already downloaded.
# Subtitles for video fZDI-kaNHe8 already downloaded.
# Subtitles for video b8YzYjv39iw already downloaded.
# Subtitles for video 9jNle6ywmUA already downloaded.
# Subtitles for video MFrQPQG1HhA already downloaded.
# Subtitles for video j_1TznHqoaY already downloaded.
# Subtitles for video rAY2TC26UrQ already downloaded.
# Subtitles for video T8gIeQEPSqc already downloaded.
# Subtitles for video WPX3Xu6ZFuc already downloaded.
# Subtitles for video D-pyzjjayyI already downloaded.
# Subtitles for video CWFOzWiBcPY already downloaded.
# Subtitles for video SAsyfdF2uck already downloaded.
# Subtitles for video FwJclWxuf0Q already downloaded.
# Subtitles for video _zRwPnupMFw already downloaded.
# Subtitles for video PxilVwQuNn4 already downloaded.
# Subtitles for video YOaWXTv7JNs already downloaded.
# Subtitles for video jzNVTarfS5A already downloaded.
# Subtitles for video NYL-y0quL10 already downloaded.
# Subtitles for video gCpV3sr2eSg already downloaded.
# Checking channel: UC1dCBgJnwO5fgNVEn2BgQbg
# Subtitles for video hUIU3uKqIgc already downloaded.
# Subtitles for video fYg7uk1CUcU already downloaded.
# Subtitles for video SS7NCSZnsks already downloaded.
# Subtitles for video W6ltkla0v6g already downloaded.
# Subtitles for video HxZKhK7jHYw already downloaded.
# Subtitles for video kI3nZ85ZlAU already downloaded.
# Subtitles for video 7w8TvLbwX5s already downloaded.
# Subtitles for video C3RRBPN-SFs already downloaded.
# Subtitles for video 3jMr41NVsFA already downloaded.
# Subtitles for video j5K2nsqBzhw already downloaded.
# Subtitles for video uzfq4nqnKLQ already downloaded.
# Subtitles for video X3DLdtwYtYs already downloaded.
# Subtitles for video ulxGBALxcYY already downloaded.
# Subtitles for video BuKNw59-Gek already downloaded.
# Subtitles for video UxTKM49GWAA already downloaded.
# Subtitles for video 5Znq284ZUUQ already downloaded.
# Subtitles for video V2O6f8iP57s already downloaded.
# Subtitles for video -kdrA42jbjk already downloaded.
# Subtitles for video brhvHPpXpNY already downloaded.
# Subtitles for video r0y1FFISeXE already downloaded.
# Subtitles for video rJsJNmtrILI already downloaded.
# Subtitles for video DZ8PNITnYaU already downloaded.
# Subtitles for video lPJ5twvRZVA already downloaded.
# Subtitles for video w5XnfXmsFPA already downloaded.
# Subtitles for video mhu8YTaNEes already downloaded.
# Subtitles for video daPTtzHWFNA already downloaded.
# Fetching subtitles for video: The ‘third inning’ of the energy transition [partner content] (B0bBqPIdc0Y)
# No subtitles available for video B0bBqPIdc0Y:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=B0bBqPIdc0Y! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Subtitles for video ORl2cGIgAU4 already downloaded.
# Subtitles for video RTtdSQvhQds already downloaded.
# Subtitles for video 3As4VY8Ubes already downloaded.
# Fetching subtitles for video: TEA breakdown: green ammonia and synthetic methane (4QlFjElF240)
# No subtitles available for video 4QlFjElF240:
# Could not retrieve a transcript for the video https://www.youtube.com/watch?v=4QlFjElF240! This is most likely caused by:
#
# Subtitles are disabled for this video
#
# If you are sure that the described cause is not responsible for this error and that a transcript should be retrievable, please create an issue at https://github.com/jdepoix/youtube-transcript-api/issues. Please add which version of youtube_transcript_api you are using and provide the information needed to replicate the error. Also make sure that there are no open issues which already describe your problem!
# Subtitles for video xbEE6Hl6Rro already downloaded.
# Subtitles for video Km1Y1uSWVTw already downloaded.
# Subtitles for video ulRWfVcSu_8 already downloaded.
# Subtitles for video Co8Ukh6p0vU already downloaded.
# Subtitles for video g0l2asDoRbI already downloaded.
# Subtitles for video PqAj5JC9D18 already downloaded.
# Subtitles for video SqD3T3OIAow already downloaded.
# Subtitles for video _FOoKYsQa1c already downloaded.
# Subtitles for video k2cfWBujfrY already downloaded.
# Subtitles for video bd9AwRTwza4 already downloaded.
# Subtitles for video j2Dmta4OzcY already downloaded.
# Subtitles for video XY-FpK-kBRg already downloaded.
# Subtitles for video AKlzIg9oDKY already downloaded.
# Subtitles for video TwYfhIIxS1o already downloaded.
# Subtitles for video IJdv7CZw4MI already downloaded.
# Subtitles for video H0LtWCVetHk already downloaded.
# Subtitles for video 84Ddg4ruoQ4 already downloaded.
# Subtitles for video 9nY-aUMb1-w already downloaded.
# Subtitles for video xsJtcUu2tyM already downloaded.
# Checking channel: UCaN2F4EwEaa8lr9u11fhA4g
# Subtitles for video Bn0TYrcXEAw already downloaded.
# Subtitles for video ISCqusrwm6g already downloaded.
# Subtitles for video J7OgFc1RwsM already downloaded.
# Subtitles for video eo0AtMq68pE already downloaded.
# Subtitles for video -O7MoeBucvI already downloaded.
# Subtitles for video svxlj504NeM already downloaded.
# Subtitles for video DxsJNlNCDCM already downloaded.
# Subtitles for video TX3VRfouiEo already downloaded.
# Subtitles for video AGFJ1pGixpM already downloaded.
# Subtitles for video kAw8eI0vX1o already downloaded.
# Subtitles for video ih25P-A4Heo already downloaded.
# Subtitles for video ImOr9gHm8_Q already downloaded.
# Subtitles for video UolXss0BS8k already downloaded.
# Subtitles for video LfBBABKUJIA already downloaded.
# Subtitles for video bn7XLAW4ATQ already downloaded.
# Subtitles for video zUjygfLmReQ already downloaded.
# Subtitles for video kcXLanRoG4Q already downloaded.
# Subtitles for video GnsNWEvX1uo already downloaded.
# Subtitles for video BmC_EEAqO9o already downloaded.
# Subtitles for video ThbO26gXIGc already downloaded.
# Subtitles for video 6nEax-QiCO4 already downloaded.
# Subtitles for video fnHzO1EsK8M already downloaded.
# Subtitles for video -Nq-VVXmUBc already downloaded.
# Subtitles for video FHlSAavBHU4 already downloaded.
# Subtitles for video TFLVRzHcUTc already downloaded.
# Subtitles for video Zofbfr8JbtI already downloaded.
# Subtitles for video YVa5CtRaKYk already downloaded.
# Subtitles for video lDt9-Q-ctwU already downloaded.
# Subtitles for video 4IDe77oechw already downloaded.
# Subtitles for video 6t9me9HaTo0 already downloaded.
# Subtitles for video nkuuZdtcEBI already downloaded.
# Subtitles for video THUifNaCQhY already downloaded.
# Subtitles for video epFICNWUtL8 already downloaded.
# Subtitles for video GU_qPntZjRM already downloaded.
# Subtitles for video 0w_cDJwubmU already downloaded.
# Subtitles for video qILTFpoQ0wk already downloaded.
# Subtitles for video PTxWUBp-Pik already downloaded.
# Subtitles for video 8_U_IFWkqic already downloaded.
# Subtitles for video 6fhgW2oYD5U already downloaded.
# Subtitles for video toqXFmfVDNk already downloaded.
# Subtitles for video mQg4Z8mYoso already downloaded.
# Subtitles for video evsFch8y1-Y already downloaded.
# Subtitles for video dCUjxaVzEok already downloaded.
# Subtitles for video Py96G9mXe_M already downloaded.
# Subtitles for video Gm5q_iKWkfw already downloaded.
# Subtitles for video xKY-OLmNf_w already downloaded.
# Subtitles for video Zf7NlgxrFbs already downloaded.
# Subtitles for video ouXhIQRZ0ME already downloaded.
# Subtitles for video uhrH078-lgU already downloaded.
# Subtitles for video E18W1G8C6lo already downloaded.
# Checking channel: UCwfzou04Z-nK0bRHc-L8zLA
# Subtitles for video cfPjA4-rG2g already downloaded.
# Subtitles for video RWglyi76TCc already downloaded.
# Subtitles for video -NtHpmpHIR8 already downloaded.
# Subtitles for video r8pi2dbAvpo already downloaded.
# Subtitles for video MpX7Fi1hzQw already downloaded.
# Subtitles for video SJ1UHhdCXlc already downloaded.
# Subtitles for video xmylLiEjU8Q already downloaded.
# Subtitles for video I-qZ-XDReo0 already downloaded.
# Subtitles for video h-RSKq2OSDg already downloaded.
# Subtitles for video IJ9c6n55AZA already downloaded.
# Subtitles for video hUB8Pk0KAKE already downloaded.
# Subtitles for video vb4qhhwzwAo already downloaded.
# Subtitles for video ckxQjKQWwdk already downloaded.
# Subtitles for video LiWFQPdZ7jo already downloaded.
# Subtitles for video zFXQK_FZ1fc already downloaded.
# Subtitles for video rvqcA1xHidU already downloaded.
# Subtitles for video Ut2Lv4hwPJ4 already downloaded.
# Subtitles for video mByV8yfmrZI already downloaded.
# Subtitles for video 4uarTLjPvC0 already downloaded.
# Subtitles for video DSbj5j5tr9w already downloaded.
# Subtitles for video OegaF_3GDao already downloaded.
# Subtitles for video jeKZzyV4YAg already downloaded.
# ...
# Subtitles for video CVx9IB_U9X4 already downloaded.
# Subtitles for video DcWqzZ3I2cY already downloaded.
# Checking channel: UC8YFh5opXFzzwfMAheZFqAw
# Subtitles for video jRfY3A-Jb9E already downloaded.
# Subtitles for video 4hx9wEkck4Q already downloaded.
# Subtitles for video uwOArdE32KM already downloaded.
# Subtitles for video WoTmOxEgaOQ already downloaded.
# Subtitles for video XKct_yyMoDo already downloaded.
# Subtitles for video r3LNgYmxEY8 already downloaded.
# Subtitles for video VWOeX6FS-zo already downloaded.
# Subtitles for video C5L2o0RpPOo already downloaded.
# Subtitles for video 0_yUza7hcAM already downloaded.
# Subtitles for video LQ6v7TomroY already downloaded.
# Subtitles for video WEI8tBBldlg already downloaded.
# Subtitles for video URSWL7vCaME already downloaded.
# Subtitles for video UpQNcAoeH-E already downloaded.
# Subtitles for video j9yvMBzafJw already downloaded.
# Subtitles for video ZB3hm8YYCYA already downloaded.
# Subtitles for video Q5EaXo9T1vM already downloaded.
# Subtitles for video OOCDXvegB0s already downloaded.
# Subtitles for video Dvzq7orgH1U already downloaded.
# Subtitles for video XC8FtI6yiKU already downloaded.
# Subtitles for video a7mbdfshmuc already downloaded.
# Subtitles for video G4VLxlisWX4 already downloaded.
# Subtitles for video fbCDvqeO64g already downloaded.
# Subtitles for video cmg3LfJZORw already downloaded.
# Subtitles for video DY-wGG_OgxI already downloaded.
# Subtitles for video 1h4yTIeT3iE already downloaded.
# Subtitles for video Y4PJyzS_WcI already downloaded.
# Subtitles for video OaKJlvvCXxo already downloaded.
# Subtitles for video bVjobBGLxMI already downloaded.
# Subtitles for video mgoGcC-ov2k already downloaded.
# Subtitles for video gjVRBqezVzU already downloaded.
# Subtitles for video oDkeGC-kYpo already downloaded.
# Subtitles for video eCY9cQKNDfs already downloaded.
# Subtitles for video Jqqky30WOUE already downloaded.
# Subtitles for video NU9MVKLovyM already downloaded.
# Subtitles for video pR-SlpuDjnQ already downloaded.
# Subtitles for video HLXQrZ_fwFc already downloaded.
# Subtitles for video E2hYW_lw9yc already downloaded.
# Subtitles for video xskuYPeJf-E already downloaded.
# Subtitles for video hlM5moQDL2o already downloaded.
# Subtitles for video sfZmUXz1qlY already downloaded.
# Subtitles for video VvanJIobL5c already downloaded.
# Subtitles for video sYVYa13190E already downloaded.
# Subtitles for video hMEWRQVOq14 already downloaded.
# Subtitles for video 421Bp25Ij5A already downloaded.
# Subtitles for video xNuEToxURuA already downloaded.
# Subtitles for video DWcGe1NVaQc already downloaded.
# Subtitles for video 9Wy_3H-edsk already downloaded.
# Subtitles for video W5a92YTFgpg already downloaded.
# Subtitles for video wx9Ej7buhhI already downloaded.
# Subtitles for video YfwC1NG4xqc already downloaded.
# Checking channel: UCvxm0qTrGN_1LMYgUaftWyQ
# Subtitles for video 4cVgWzotmb8 already downloaded.
# Subtitles for video sEZ9lutW5-I already downloaded.
# Subtitles for video AV0WZ0xjQ_k already downloaded.
# Subtitles for video DpwTMY4Vnzw already downloaded.
# Subtitles for video cAfPLCQPNhI already downloaded.
# Subtitles for video 06KRMVoTjbs already downloaded.
# Subtitles for video OnqE249s-64 already downloaded.
# Subtitles for video qfgSeCNZlbk already downloaded.
# Subtitles for video NPny3eW6dQY already downloaded.
# Subtitles for video pTYUI9KvjoI already downloaded.
# Subtitles for video v1HXT2js-v0 already downloaded.
# Subtitles for video QiJLzIgWABI already downloaded.
# Subtitles for video PvtB3Rw2zZk already downloaded.
# Subtitles for video o13rhcyuL30 already downloaded.
# Subtitles for video vyBenVL09xs already downloaded.
# Subtitles for video kAn-ep3VOjU already downloaded.
# Subtitles for video sjLQ0IYPcik already downloaded.
# Subtitles for video Y0PCpO627yU already downloaded.
# Subtitles for video sr4BIkWIYsM already downloaded.
# Subtitles for video ibWkHGOvfBM already downloaded.
# Subtitles for video cJuJtQrC08Y already downloaded.
# Subtitles for video _MUgqHpqvPs already downloaded.
# Subtitles for video 6Om7DqPRVvc already downloaded.
# Subtitles for video k8HMXMVwPn0 already downloaded.
# Subtitles for video APzpN0iSfIQ already downloaded.
# Subtitles for video LY6zVGMMbVg already downloaded.
# Subtitles for video V1zQ2ySKxiA already downloaded.
# Subtitles for video xRi3aqUlBsE already downloaded.
# Subtitles for video F2fFqcTdqIc already downloaded.
# Subtitles for video aLIFiq6eVm4 already downloaded.
# Subtitles for video -gIUz9vWQaY already downloaded.
# Subtitles for video -DEOooVD7H0 already downloaded.
# Subtitles for video bKJC3fwIhqw already downloaded.
# Subtitles for video t8hSqgeNR1I already downloaded.
# Subtitles for video M_FrqzV54Ss already downloaded.
# Subtitles for video fhB_ZX2XGf0 already downloaded.
# Subtitles for video kbG2CWrmKTw already downloaded.
# Subtitles for video c-jdJMR2ENs already downloaded.
# Subtitles for video Xh3Mz_lBq1w already downloaded.
# Subtitles for video hVHG_WWx2Y4 already downloaded.
# Subtitles for video qcUsCkIU4KI already downloaded.
# Subtitles for video RgJM1Yp5ajE already downloaded.
# Subtitles for video yJTZkdfXMxs already downloaded.
# Subtitles for video HR4oWQuCXSA already downloaded.
# Subtitles for video 9d3jLTRef_I already downloaded.
# Subtitles for video _Uz0G85wJOc already downloaded.
# Subtitles for video 9tbxXEQT5rg already downloaded.
# Subtitles for video FGLXdubIazs already downloaded.
# Subtitles for video LE6-b3Hanjo already downloaded.
# Subtitles for video WIE5zkDarKI already downloaded.
# Checking channel: UCdMrj5kezVrTiqZoFRqGxAg
# Subtitles for video 0N5x5ssuSsQ already downloaded.
# Subtitles for video L5-Q6vL6Ok4 already downloaded.
# Subtitles for video gQJsCzUWwkI already downloaded.
# Subtitles for video Qzu5bgJofdI already downloaded.
# Subtitles for video 6vxr9MfXBEc already downloaded.
# Subtitles for video zFXIiLt5L9Q already downloaded.
# Subtitles for video tzFOXGLV93M already downloaded.
# Subtitles for video Ww3w4co7d2A already downloaded.
# Subtitles for video yowhTo8oXz0 already downloaded.
# Subtitles for video EtgquVexj2o already downloaded.
# Subtitles for video fKUETJ9bETw already downloaded.
# Subtitles for video cQJ-60ctPBA already downloaded.
# Subtitles for video -IzMETPko4Y already downloaded.
# Subtitles for video 4KS0frYusjk already downloaded.
# Subtitles for video FAKgPz9caaw already downloaded.
# Subtitles for video p3Lg-Ka6MhI already downloaded.
# Subtitles for video QKV7msvEv0E already downloaded.
# Subtitles for video -Y3nBd1jhmo already downloaded.
# Subtitles for video dOfHhaLI9aE already downloaded.
# Subtitles for video 0JfRPXYFQHE already downloaded.
# Subtitles for video EXMTbeCM-9Y already downloaded.
# Subtitles for video 8oCYbliC6go already downloaded.
# Subtitles for video ZGRLZSAyekY already downloaded.
# Subtitles for video 9KwYZqN2EIc already downloaded.
# Subtitles for video SYvDw3d60aU already downloaded.
# Subtitles for video I8dJ111nHaE already downloaded.
# Subtitles for video IQ20dby8ujY already downloaded.
# Subtitles for video eR2coEfoAoM already downloaded.
# Subtitles for video QXLzOLp6bXs already downloaded.
# Subtitles for video dwscDrsbsjw already downloaded.
# Subtitles for video 1kHUsdRGcNM already downloaded.
# Subtitles for video 3-YS7UJ8KDI already downloaded.
# Subtitles for video 2mMiVBmGxnY already downloaded.
# Subtitles for video x1tRGiFODag already downloaded.
# Subtitles for video EcwjxiXNAGU already downloaded.
# Subtitles for video bFPgxGR4MMU already downloaded.
# Subtitles for video kJSGh69DAl8 already downloaded.
# Subtitles for video i_4g5CzAoHE already downloaded.
# Subtitles for video A7NMgAG8RJA already downloaded.
# Subtitles for video 3LI_GW7SjcI already downloaded.
# Subtitles for video VvBNAKidqrs already downloaded.
# Subtitles for video TzilqW4WbAE already downloaded.
# Subtitles for video PZmSIuh1VV4 already downloaded.
# Subtitles for video FUlKbgmOa9M already downloaded.
# Subtitles for video PAu98nxQpWE already downloaded.
# Subtitles for video N1LH6XixCao already downloaded.
# Subtitles for video UzCp9hMOs_I already downloaded.
# Subtitles for video PYPocXDWyVM already downloaded.
# Subtitles for video 6j5WdPC8Xck already downloaded.
# Subtitles for video xJK90xjJ7pM already downloaded.
# Checking channel: UCMLtBahI5DMrt0NPvDSoIRQ
# Subtitles for video kRUbtQmv-iQ already downloaded.
# Subtitles for video 1kwbp8hRRfs already downloaded.
# Subtitles for video x_FkLHzzwY0 already downloaded.
# Subtitles for video s5nC0gJx-l0 already downloaded.
# Subtitles for video PHBItVuudbU already downloaded.
# Subtitles for video jKEvXXQI5Y4 already downloaded.
# Subtitles for video _Aj8Pp-feDU already downloaded.
# Subtitles for video Jr_nGkCG3og already downloaded.
# Subtitles for video snBHdvauoF8 already downloaded.
# Subtitles for video mTX_sAq--zY already downloaded.
# Subtitles for video m9d_5EjwXzo already downloaded.
# Subtitles for video 8u2pW2zZLCs already downloaded.
# Subtitles for video l3O2J3LMxqI already downloaded.
# Subtitles for video Kt6_FKaKBPA already downloaded.
# Subtitles for video Q9ex_uLah_c already downloaded.
# Subtitles for video 3km4s2MKwEY already downloaded.
# Subtitles for video H_krso45qs0 already downloaded.
# Subtitles for video n4ipEJ6uJ44 already downloaded.
# Subtitles for video tElHFvAZh3I already downloaded.
# Subtitles for video 2xFTNXK6AzQ already downloaded.
# Subtitles for video 14DXtvRJeNU already downloaded.
# Subtitles for video E5u5cad3uJw already downloaded.
# Subtitles for video fZYUqICYCAk already downloaded.
# Subtitles for video G1ARvwQntAU already downloaded.
# Subtitles for video w9WE1aOPjHc already downloaded.
# Subtitles for video mw5WIDGRLnA already downloaded.
# Subtitles for video yo56q983Ni0 already downloaded.
# Subtitles for video YpFaPKOeNME already downloaded.
# Subtitles for video C6sSs6NgANo already downloaded.
# Subtitles for video XFMk0snybAc already downloaded.
# Subtitles for video BJMi_dAwE8k already downloaded.
# Subtitles for video VgPrjHxIS0I already downloaded.
# Subtitles for video vei7uf9wOxI already downloaded.
# Subtitles for video RvVCyCmsCjg already downloaded.
# Subtitles for video xjH2B_sE_RQ already downloaded.
# Subtitles for video JTU8Ha4Jyfc already downloaded.
# Subtitles for video -M0HZGKF4UI already downloaded.
# Subtitles for video URtF_UHYBSo already downloaded.
# Subtitles for video sySQXEjTKFw already downloaded.
# Subtitles for video 6w5xr8BYV8M already downloaded.
# Subtitles for video k6eXkBtYIHg already downloaded.
# Subtitles for video hf18w6CuY8o already downloaded.
# Subtitles for video 3MkJEGE9GRY already downloaded.
# Subtitles for video 3ZTNps2PraM already downloaded.
# Subtitles for video 7bmhjt1cpRs already downloaded.
# Subtitles for video ZTE-JVd_QkA already downloaded.
# Subtitles for video s7_NlkBwdj8 already downloaded.
# Subtitles for video nnBbpPt2SKI already downloaded.
# Subtitles for video I0PLTzeEbtg already downloaded.
# Subtitles for video 6DrCq8Ry2cw already downloaded.
# Checking channel: UCZ4AMrDcNrfy3X6nsU8-rPg
# Subtitles for video bG6-JX_iYQM already downloaded.
# Subtitles for video nf6UIJk1NOI already downloaded.
# Subtitles for video 1EkIpMkCVwk already downloaded.
# Subtitles for video 1KpjV-p59k8 already downloaded.
# Subtitles for video CF4qM429Brk already downloaded.
# Subtitles for video K0V8kZyl1T0 already downloaded.
# Subtitles for video TBAlPuwIlNM already downloaded.
# Subtitles for video zqeaauoiK6k already downloaded.
# Subtitles for video Y8tzMOzTTFQ already downloaded.
# Subtitles for video 3M690082Y0s already downloaded.
# Subtitles for video M2LrHMKFcdU already downloaded.
# Subtitles for video VX7rws4lPg8 already downloaded.
# Subtitles for video evIAnt5mNGI already downloaded.
# Subtitles for video FThf9X-pwQs already downloaded.
# Subtitles for video BLH6Z1-t5e0 already downloaded.
# Subtitles for video P60TX-dwd4s already downloaded.
# Subtitles for video V4hL-yJN6eY already downloaded.
# Subtitles for video 3DG5xiv4I1w already downloaded.
# Subtitles for video KC3pxFcdGFg already downloaded.
# Subtitles for video DCkOvmVxWcw already downloaded.
# Subtitles for video TuadTdhmne0 already downloaded.
# Subtitles for video Dx_C1fOT4gQ already downloaded.
# Subtitles for video EdlKQ6sSb_o already downloaded.
# Subtitles for video bxvHAaa9PKA already downloaded.
# Subtitles for video U4jqQ6RTWNg already downloaded.
# Subtitles for video -tmixPEOMIA already downloaded.
# Subtitles for video XkE9cunv62E already downloaded.
# Subtitles for video k4Tw-vJBzMo already downloaded.
# Subtitles for video PaHKRBGT_6A already downloaded.
# Subtitles for video 98bIRV-jzMs already downloaded.
# Subtitles for video 6Su-5dq-MYg already downloaded.
# Subtitles for video GY7HTeTWleY already downloaded.
# Subtitles for video PWCxj__3Xx4 already downloaded.
# Subtitles for video tEVAYEtHlHk already downloaded.
# Subtitles for video A2tS83sGx40 already downloaded.
# Subtitles for video aEirB081k1A already downloaded.
# Subtitles for video qcea8YFFzh0 already downloaded.
# Subtitles for video NZXmd2Jxpx4 already downloaded.
# Subtitles for video 6UYK0ayEW08 already downloaded.
# Subtitles for video Y6-I5BHsEck already downloaded.
# Subtitles for video 9uHsgRoNVX8 already downloaded.
# Subtitles for video CKLx3J7U6_Q already downloaded.
# Subtitles for video DmMmnSIQmx8 already downloaded.
# Subtitles for video 7Ody9AGVuQ8 already downloaded.
# Subtitles for video nK5atJjdf08 already downloaded.
# Subtitles for video 1k8TXQWVsoI already downloaded.
# Subtitles for video CxmH4OLNM4c already downloaded.
# Subtitles for video Z446bPzkt4c already downloaded.
# Subtitles for video C1Gs0uqqggc already downloaded.
# Subtitles for video oUVrVEviaHo already downloaded.
# Checking channel: UCUyDOdBWhC1MCxEjC46d-zw
# Subtitles for video 6OQfobJGe0Y already downloaded.
# Subtitles for video iDHLRoB-mvQ already downloaded.
# Subtitles for video fp9REQFC2g8 already downloaded.
# Subtitles for video dy1Xlo4c-KA already downloaded.
# Subtitles for video HwPXctiw_rY already downloaded.
# Subtitles for video -HWa1hHGAt0 already downloaded.
# Subtitles for video fC6T4Ca60oM already downloaded.
# Subtitles for video kIW1CTBzu5s already downloaded.
# Subtitles for video pXjO-6DIYBU already downloaded.
# Subtitles for video MHILW3eMmfQ already downloaded.
# Subtitles for video JORS29FKfgs already downloaded.
# Subtitles for video s4ZAaNimVLQ already downloaded.
# Subtitles for video -Oih_QxPW4Q already downloaded.
# Subtitles for video XS1Bqw60VPw already downloaded.
# Subtitles for video jOSPJmSFTQs already downloaded.
# Subtitles for video v27GrNh7VTA already downloaded.
# Subtitles for video _AZVkJBkxvw already downloaded.
# Subtitles for video CENGRXQd1Yo already downloaded.
# Subtitles for video J4rUw-45QMs already downloaded.
# Subtitles for video ZS8Zo-dBiz8 already downloaded.
# Subtitles for video d29yQlxH4LA already downloaded.
# Subtitles for video QwEb78e5a8Y already downloaded.
# Subtitles for video PAYkFA-RF4s already downloaded.
# Subtitles for video VZmCS9TYUgo already downloaded.
# Subtitles for video vM22czeEVl4 already downloaded.
# Subtitles for video OLwKAIRYd_w already downloaded.
# Subtitles for video v1rQL1-Ywg8 already downloaded.
# Subtitles for video k4oeH840ouw already downloaded.
# Subtitles for video y14UX7Fp-Ow already downloaded.
# Subtitles for video 1uRZilaI_O0 already downloaded.
# Subtitles for video Kvgwgu7ceHM already downloaded.
# Subtitles for video _9yrNW4GpUc already downloaded.
# Subtitles for video OXleZ-BaEO0 already downloaded.
# Subtitles for video npi7UeOE_0o already downloaded.
# Subtitles for video 6QJmeqzxTLw already downloaded.
# Subtitles for video sBJppqCeFGI already downloaded.
# Subtitles for video rT5TALmnjJI already downloaded.
# Subtitles for video t3YXp4KVAwc already downloaded.
# Subtitles for video b4mUR8KreCg already downloaded.
# Subtitles for video qrmm6RaZyI4 already downloaded.
# Subtitles for video OP0u_lSkXR0 already downloaded.
# Subtitles for video mjZhNn9_owk already downloaded.
# Subtitles for video AX3oidjc5Cs already downloaded.
# Subtitles for video 0UTkT4mwaTs already downloaded.
# Subtitles for video i1TuDe4i4MU already downloaded.
# Subtitles for video SdXffC1oHBs already downloaded.
# Subtitles for video 8tojm5FnA-8 already downloaded.
# Subtitles for video Mft3DFYa0_I already downloaded.
# Subtitles for video eX3Ch_HuR70 already downloaded.
# Subtitles for video bHrnwVhFpcc already downloaded.
# End
