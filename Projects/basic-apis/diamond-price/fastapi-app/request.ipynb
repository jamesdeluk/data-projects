# %%
import requests

url = "http://127.0.0.1:8000/predict"
data = {
    "carat":1.5,
    "cut":4,
    "color":4,
    "clarity":4,
    "x":3,
    "y":3,
    "z":3
}

response = requests.post(url, json=data)

if response.status_code == 200:
    print(response.json())
else:
    print("Error:", response.status_code, response.text)
# Out:
# {'input': {'carat': 1.5, 'cut': 4, 'color': 4, 'clarity': 4, 'x': 3.0, 'y': 3.0, 'z': 3.0}, 'price': 10123.14}

# %%
import requests
import time

url = "http://127.0.0.1:8000/predict-named"
data = {
    "carat":1,
    "cut":3,
    "color":3,
    "clarity":3,
    "x":3,
    "y":3,
    "z":3
}

start_time = time.time()
response = requests.post(url, json=data)
end_time = time.time()
duration = end_time - start_time
print(f"Request took {duration:.2f} seconds")

if response.status_code == 200:
    print(response.json())
else:
    print("Error:", response.status_code, response.text)

url = "http://127.0.0.1:8000/predict-list"
data = [1,3,3,3,3,3,3]

start_time = time.time()
response = requests.post(url, json=data)
end_time = time.time()
duration = end_time - start_time
print(f"Request took {duration:.2f} seconds")

if response.status_code == 200:
    print(response.json())
else:
    print("Error:", response.status_code, response.text)

url = "http://127.0.0.1:8000/predict"
data = {
    "carat":1,
    "cut":3,
    "color":3,
    "clarity":3,
    "x":3,
    "y":3,
    "z":3
}

start_time = time.time()
response = requests.post(url, json=data)
end_time = time.time()
duration = end_time - start_time
print(f"Request took {duration:.2f} seconds")

if response.status_code == 200:
    print(response.json())
else:
    print("Error:", response.status_code, response.text)

url = "http://127.0.0.1:8000/predict"
data = [1,3,3,3,3,3,3]

start_time = time.time()
response = requests.post(url, json=data)
end_time = time.time()
duration = end_time - start_time
print(f"Request took {duration:.2f} seconds")

if response.status_code == 200:
    print(response.json())
else:
    print("Error:", response.status_code, response.text)
