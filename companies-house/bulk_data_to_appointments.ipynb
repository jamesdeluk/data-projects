# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# del data

# data = pd.read_pickle("data.pkl")

# file_paths = [file for file in os.listdir('.') if file.endswith('.dat')]
file_path = "Prod195_3847_ew_7.dat"
# with open(file_path, 'r') as file:
#     print(sum(1 for _ in file))

start_line = 5000001
end_line = 6715260
# 6715260

# %%
person_record_colspecs = [ (0,8), (10,12), (32,40), (40,48), (56,64), (76,1201) ]
person_record_names = [ "Company Number", "Appointment Type", "Appointment Date", "Resignation Date", "Partial Date of Birth", "Variable Data" ]
company_record_colspecs = [ (0,8), (9,10), (40,201) ]
company_record_names = [ "Company Number", "Company Status", "Company Name" ]

def detect_colspec(line):
    if line[8] == '1':
        return company_record_colspecs, company_record_names
    elif line[8] == '2':
        return person_record_colspecs, person_record_names
    else:
        print(line)
        return [],[]

def process_line_range(file_path, start_line, end_line):
    company_records = []
    person_records = []
    
    with open(file_path, 'r') as file:
        # Use enumerate to track line numbers
        for line_number, line in tqdm(enumerate(file, start=1), desc="Processing items", total=end_line, mininterval=1):
            if line_number < start_line:
                continue  # Skip lines before the start line
            if line_number > end_line:
                break  # Stop when reaching the end line
            
            # Process the current line
            colspecs, names = detect_colspec(line)
            if colspecs != []:
                parsed_line = pd.read_fwf(pd.io.common.StringIO(line), colspecs=colspecs, names=names)
                if "Company Status" in names:
                    company_records.append(parsed_line)
                else:
                    person_records.append(parsed_line)
    
    # Convert to DataFrames
    print(f'{pd.Timestamp.now()}: Converting to DataFrames')
    df_company = pd.concat(company_records, ignore_index=True) if company_records else pd.DataFrame(columns=company_record_names)
    df_person = pd.concat(person_records, ignore_index=True) if person_records else pd.DataFrame(columns=person_record_names)
    
    return df_company, df_person

if "data" not in globals():
    data = pd.DataFrame()

df_company, df_person = process_line_range(file_path, start_line, end_line)

print(f'{pd.Timestamp.now()}: Merging new data')
new_data = pd.merge(df_person, df_company, on="Company Number", how="inner")

print(f'{pd.Timestamp.now()}: Cleaning data')
new_data['Company Status'] = new_data['Company Status'].fillna('A')
new_data['Person Name'] = new_data['Variable Data'].str.split('<<<<').str[0].str.replace('<',' ')
new_data['Company Name'] = new_data['Company Name'].str.replace('<',' ')
new_data = new_data.drop(['Variable Data'], axis=1)

print(f'{pd.Timestamp.now()}: Making new columns')
new_data['Appointment Date'] = pd.to_datetime(new_data['Appointment Date'].astype(int).astype(str), format='%Y%m%d')
new_data['Partial Date of Birth'] = pd.to_datetime(new_data['Partial Date of Birth'].dropna().astype(int).astype(str), format='%Y%m', errors='coerce')
today = pd.Timestamp.now()
new_data['Current Age'] = new_data['Partial Date of Birth'].apply(lambda x: today.year - x.year - ((today.month, today.day) < (x.month, x.day)) if pd.notnull(x) else np.nan)
def calculate_tenure(row):
    if pd.isnull(row['Resignation Date']):
        current_tenure = today.year - row['Appointment Date'].year - ((today.month, today.day) < (row['Appointment Date'].month, row['Appointment Date'].day))
        return pd.Series({'Current Tenure': current_tenure, 'Time Since Leaving': np.nan, 'Total Tenure': np.nan})
    else:
        time_since_leaving = today.year - row['Resignation Date'].year - ((today.month, today.day) < (row['Resignation Date'].month, row['Resignation Date'].day))
        total_tenure = (row['Resignation Date'] - row['Appointment Date']).days / 365.25  # Total tenure in years
        return pd.Series({'Current Tenure': np.nan, 'Time Since Leaving': time_since_leaving, 'Total Tenure': total_tenure})
new_data[['Current Tenure', 'Time Since Leaving', 'Total Tenure']] = new_data.apply(calculate_tenure, axis=1)

print(f'{pd.Timestamp.now()}: Merging data')
data = pd.concat([data, new_data], ignore_index=True)
# Out:
# Processing items:   0%|          | 0/6715260 [00:00<?, ?it/s]
# Processing items: 100%|██████████| 6715260/6715260 [24:51<00:00, 4502.56it/s]
# 9999999906715258
#
# 2024-12-13 09:07:37.300242: Converting to DataFrames
# 2024-12-13 09:10:38.003686: Merging new data
# 2024-12-13 09:10:38.764897: Cleaning data
# 2024-12-13 09:10:41.002803: Making new columns
# 2024-12-13 09:14:18.288076: Merging data

# %%
data.to_pickle("data.pkl")

# %%
data
# Out:
#          Company Number  Appointment Type Appointment Date  Resignation Date  \
# 0                     6                 0       2016-09-13               NaN
# 1                     6                 1       2015-03-01               NaN
# 2                     6                 1       2015-06-01               NaN
# 3                    58                 0       1992-01-26               NaN
# 4                    58                 1       2004-09-24               NaN
# ...                 ...               ...              ...               ...
# 26099735       ZC000205                 1       2001-06-30               NaN
# 26099736       ZC000205                 1       2014-01-01               NaN
# 26099737       ZC000205                 1       2019-12-27               NaN
# 26099738       ZC000205                 1       2019-12-27               NaN
# 26099739       ZC000205                 1       2016-07-21               NaN
#
#          Partial Date of Birth Company Status  \
# 0                          NaT              D
# 1                   1963-03-01              D
# 2                   1952-10-01              D
# 3                          NaT              D
# 4                   1963-03-01              D
# ...                        ...            ...
# 26099735            1958-12-01              A
# 26099736            1953-08-01              A
# 26099737            1973-01-01              A
# 26099738            1964-07-01              A
# 26099739            1951-11-01              A
#
#                                                Company Name  \
# 0         MARINE AND GENERAL MUTUAL LIFE ASSURANCE SOCIETY
# 1         MARINE AND GENERAL MUTUAL LIFE ASSURANCE SOCIETY
# 2         MARINE AND GENERAL MUTUAL LIFE ASSURANCE SOCIETY
# 3                     RAILWAY PASSENGERS ASSURANCE COMPANY
# 4                     RAILWAY PASSENGERS ASSURANCE COMPANY
# ...                                                     ...
# 26099735           THE FELIXSTOWE DOCK AND RAILWAY COMPANY
# 26099736           THE FELIXSTOWE DOCK AND RAILWAY COMPANY
# 26099737           THE FELIXSTOWE DOCK AND RAILWAY COMPANY
# 26099738           THE FELIXSTOWE DOCK AND RAILWAY COMPANY
# 26099739           THE FELIXSTOWE DOCK AND RAILWAY COMPANY
#
#                                            Person Name  Current Age  \
# 0                                    MR MARTIN PRINGLE          NaN
# 1                                   MR JAMES GALBRAITH         61.0
# 2                               MR MICHAEL JOHN WALKER         72.0
# 3           AVIVA COMPANY SECRETARIAL SERVICES LIMITED          NaN
# 4                               STUART ALAN ROPER MEAD         61.0
# ...                                                ...          ...
# 26099735                    MR CLEMENCE CHUN FUN CHENG         66.0
# 26099736                                   SING CHI IP         71.0
# 26099737                     MR ANDREW STEVEN LAWRENCE         51.0
# 26099738                      MR SIMON RICHARD MULLETT         60.0
# 26099739                            MR FRANK JOHN SIXT         73.0
#
#           Current Tenure  Time Since Leaving  Total Tenure
# 0                    8.0                 NaN           NaN
# 1                    9.0                 NaN           NaN
# 2                    9.0                 NaN           NaN
# 3                   32.0                 NaN           NaN
# 4                   20.0                 NaN           NaN
# ...                  ...                 ...           ...
# 26099735            23.0                 NaN           NaN
# 26099736            10.0                 NaN           NaN
# 26099737             4.0                 NaN           NaN
# 26099738             4.0                 NaN           NaN
# 26099739             8.0                 NaN           NaN
#
# [26099740 rows x 12 columns]

# %%
display(data.isnull().sum())
display(data.dtypes)
display(data.describe(include='all'))
# Out:
# Company Number                  0
# Appointment Type                0
# Appointment Date                0
# Resignation Date         26099740
# Partial Date of Birth     3408560
# Company Status                  0
# Company Name                    0
# Person Name                     0
# Current Age               3408560
# Current Tenure                  0
# Time Since Leaving       26099740
# Total Tenure             26099740
# dtype: int64
# Company Number                   object
# Appointment Type                  int64
# Appointment Date         datetime64[ns]
# Resignation Date                float64
# Partial Date of Birth    datetime64[ns]
# Company Status                   object
# Company Name                     object
# Person Name                      object
# Current Age                     float64
# Current Tenure                  float64
# Time Since Leaving              float64
# Total Tenure                    float64
# dtype: object
#        Company Number  Appointment Type               Appointment Date  \
# count        26099740      2.609974e+07                       26099740
# unique       14239717               NaN                            NaN
# top          OC417204               NaN                            NaN
# freq             1990               NaN                            NaN
# mean              NaN      8.578948e-01  2010-12-26 09:31:55.114801408
# min               NaN      0.000000e+00            1899-12-31 00:00:00
# 25%               NaN      1.000000e+00            2003-08-29 00:00:00
# 50%               NaN      1.000000e+00            2012-07-18 00:00:00
# 75%               NaN      1.000000e+00            2019-11-06 00:00:00
# max               NaN      1.700000e+01            2024-12-10 00:00:00
# std               NaN      6.632895e-01                            NaN
#
#         Resignation Date          Partial Date of Birth Company Status  \
# count                0.0                       22691180       26099740
# unique               NaN                            NaN              5
# top                  NaN                            NaN              D
# freq                 NaN                            NaN       16837617
# mean                 NaN  1969-03-10 02:09:55.993192596            NaN
# min                  NaN            1692-03-01 00:00:00            NaN
# 25%                  NaN            1958-08-01 00:00:00            NaN
# 50%                  NaN            1969-07-01 00:00:00            NaN
# 75%                  NaN            1980-11-01 00:00:00            NaN
# max                  NaN            2024-11-01 00:00:00            NaN
# std                  NaN                            NaN            NaN
#
#              Company Name               Person Name   Current Age  \
# count            26099740                  26099740  2.269118e+07
# unique           13592319                  11932668           NaN
# top     DELOITTE NSE LLP     GABEM SERVICES LIMITED           NaN
# freq                 1990                     51053           NaN
# mean                  NaN                       NaN  5.526348e+01
# min                   NaN                       NaN  0.000000e+00
# 25%                   NaN                       NaN  4.400000e+01
# 50%                   NaN                       NaN  5.500000e+01
# 75%                   NaN                       NaN  6.600000e+01
# max                   NaN                       NaN  3.320000e+02
# std                   NaN                       NaN  1.576361e+01
#
#         Current Tenure  Time Since Leaving  Total Tenure
# count     2.609974e+07                 0.0           0.0
# unique             NaN                 NaN           NaN
# top                NaN                 NaN           NaN
# freq               NaN                 NaN           NaN
# mean      1.346412e+01                 NaN           NaN
# min       0.000000e+00                 NaN           NaN
# 25%       5.000000e+00                 NaN           NaN
# 50%       1.200000e+01                 NaN           NaN
# 75%       2.100000e+01                 NaN           NaN
# max       1.240000e+02                 NaN           NaN
# std       9.967168e+00                 NaN           NaN

# %%
sns.boxplot(data[(data['Company Status']=='A') & (data['Appointment Type']==1)]['Current Age'])
# Out:
# <Axes: ylabel='Current Age'>

# %%
# data[data['Current Age'] > 100]
data[(data['Company Status']=='D') & (data['Current Age'] > 120)].sort_values('Current Age', ascending=False)
# Out:
#          Company Number  Appointment Type Appointment Date  Resignation Date  \
# 2044174         2331194                 0       2008-06-30               NaN
# 14435289        8239793                 1       2012-10-04               NaN
# 12440303        7000851                 1       2009-08-26               NaN
# 13041527        7362737                 1       2010-09-10               NaN
# 25749183       OC329497                 4       2007-07-02               NaN
# ...                 ...               ...              ...               ...
# 60214            224284                 1       1991-09-12               NaN
# 61262            227143                 0       1991-01-31               NaN
# 61263            227143                 1       1991-01-31               NaN
# 69062            246733                 1       1991-07-14               NaN
# 13882300        7885032                 1       2011-12-16               NaN
#
#          Partial Date of Birth Company Status  \
# 2044174             1692-03-01              D
# 14435289            1693-12-01              D
# 12440303            1699-10-01              D
# 13041527            1709-04-01              D
# 25749183            1790-05-01              D
# ...                        ...            ...
# 60214               1903-02-01              D
# 61262               1903-10-01              D
# 61263               1903-10-01              D
# 69062               1903-05-01              D
# 13882300            1903-06-01              D
#
#                                        Company Name  \
# 2044174                             D-HOLD LIMITED
# 14435289                                 KRZYS LTD
# 12440303                        BOSAMP TRADING LTD
# 13041527                         DIGIDREAM LIMITED
# 25749183                    CANAAN INVESTMENTS LLP
# ...                                             ...
# 60214                       WILLIS & BATES LIMITED
# 61262                  FRANK MORRALL & SON LIMITED
# 61263                  FRANK MORRALL & SON LIMITED
# 69062     HARRY WILKES AND SONS (BUILDERS) LIMITED
# 13882300         UKSAS JR VEDLIKEHOLD-BYGG LIMITED
#
#                          Person Name  Current Age  Current Tenure  \
# 2044174     MR GUY JONATHAN MCCARTHY        332.0            16.0
# 14435289  MR KRZYSZTOF STRZESNIEWSKI        331.0            12.0
# 12440303            SAMSON ONWIONOKO        325.0            15.0
# 13041527      MR. TIMOTHEUS VERHEYEN        315.0            14.0
# 25749183            KIKELOMO ODELEYE        234.0            17.0
# ...                              ...          ...             ...
# 60214          MRS CARMEN OLGA BATES        121.0            33.0
# 61262                  EDITH MORRALL        121.0            33.0
# 61263                  EDITH MORRALL        121.0            33.0
# 69062         JEANETTA LILIAN WILKES        121.0            33.0
# 13882300              KESTUTIS UKSAS        121.0            12.0
#
#           Time Since Leaving  Total Tenure
# 2044174                  NaN           NaN
# 14435289                 NaN           NaN
# 12440303                 NaN           NaN
# 13041527                 NaN           NaN
# 25749183                 NaN           NaN
# ...                      ...           ...
# 60214                    NaN           NaN
# 61262                    NaN           NaN
# 61263                    NaN           NaN
# 69062                    NaN           NaN
# 13882300                 NaN           NaN
#
# [897 rows x 12 columns]

# %%
data[~data['Resignation Date'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Company Number, Appointment Type, Appointment Date, Resignation Date, Partial Date of Birth, Company Status, Company Name, Person Name, Current Age, Current Tenure, Time Since Leaving, Total Tenure]
# Index: []

# %%
data[data['Company Number'] == 12383]
# Out:
#      Company Number  Appointment Type Appointment Date  Resignation Date  \
# 1447          12383                 0       2016-11-07               NaN
# 1448          12383                 1       2024-03-08               NaN
# 1449          12383                 1       2022-11-15               NaN
# 1450          12383                 1       2022-11-15               NaN
# 1451          12383                 1       2024-03-08               NaN
# 1452          12383                 1       2024-03-08               NaN
# 1453          12383                 1       2021-12-14               NaN
# 1454          12383                 1       1991-12-31               NaN
#
#      Partial Date of Birth Company Status                Company Name  \
# 1447                   NaT              A  SHIRE HORSE SOCIETY.(THE)
# 1448            1981-08-01              A  SHIRE HORSE SOCIETY.(THE)
# 1449            1968-11-01              A  SHIRE HORSE SOCIETY.(THE)
# 1450            1961-12-01              A  SHIRE HORSE SOCIETY.(THE)
# 1451            1867-10-01              A  SHIRE HORSE SOCIETY.(THE)
# 1452            1982-11-01              A  SHIRE HORSE SOCIETY.(THE)
# 1453            1953-04-01              A  SHIRE HORSE SOCIETY.(THE)
# 1454            1942-01-01              A  SHIRE HORSE SOCIETY.(THE)
#
#                    Person Name  Current Age  Current Tenure  \
# 1447          VICTORIA CLAYTON          NaN             8.0
# 1448              DAVID CLARKE         43.0             0.0
# 1449             MR JAMES HICK         56.0             2.0
# 1450          MR SIMON LIVESEY         63.0             2.0
# 1451                HUW MURPHY        157.0             0.0
# 1452             JOHN ROBINSON         42.0             0.0
# 1453  MRS HELEN MAUREEN THOMAS         71.0             2.0
# 1454     MR THOMAS JAMES YATES         82.0            32.0
#
#       Time Since Leaving  Total Tenure
# 1447                 NaN           NaN
# 1448                 NaN           NaN
# 1449                 NaN           NaN
# 1450                 NaN           NaN
# 1451                 NaN           NaN
# 1452                 NaN           NaN
# 1453                 NaN           NaN
# 1454                 NaN           NaN

# %%
data[data['Person Name'].str.contains(r"JAMES.*GIBBINS", case=False, na=False)]
# Out:
#          Company Number  Appointment Type Appointment Date  Resignation Date  \
# 180543           483521                 0       1991-07-16               NaN
# 180544           483521                 1       1991-07-16               NaN
# 915094          1416151                 0       2012-01-31               NaN
# 2617827         2624120                 0       1991-06-26               NaN
# 2747288         2673102                 1       2000-01-01               NaN
# 2747504         2673180                 1       2000-01-01               NaN
# 3000701         2770113                 1       1993-02-15               NaN
# 3162369         2832699                 1       1993-07-06               NaN
# 3162376         2832703                 1       1993-07-27               NaN
# 3188601         2842954                 1       1993-08-06               NaN
# 5452193         3777114                 1       1999-05-26               NaN
# 5974676         3996864                 1       2000-05-18               NaN
# 6276986         4126246                 0       2000-12-15               NaN
# 6276989         4126246                 1       2004-01-01               NaN
# 6474055         4210552                 1       2001-05-03               NaN
# 6518866         4229811                 1       2002-07-30               NaN
# 6597238         4263351                 0       2001-08-02               NaN
# 6597240         4263351                 1       2001-08-02               NaN
# 6914194         4399842                 0       2005-01-29               NaN
# 10277804        5913213                 1       2006-09-11               NaN
# 10433148        5984445                 1       2006-11-01               NaN
# 11496806        6490039                 1       2020-10-27               NaN
# 11793481        6638175                 1       2018-09-01               NaN
# 12047643        6777708                 1       2008-12-21               NaN
# 12048051        6777934                 1       2008-12-22               NaN
# 12156703        6839349                 0       2009-03-06               NaN
# 12156705        6839349                 1       2009-03-06               NaN
# 12219518        6874787                 1       2011-05-30               NaN
# 12591351        7090519                 1       2009-11-30               NaN
# 12959543        7312516                 1       2010-09-29               NaN
# 13786118        7824006                 1       2011-10-26               NaN
# 13794534        7829371                 1       2011-10-31               NaN
# 13959375        7934684                 0       2013-02-26               NaN
# 13959376        7934684                 1       2012-02-03               NaN
# 14597227        8344054                 1       2013-01-02               NaN
# 14992835        8602660                 1       2013-07-09               NaN
# 15369891        8852551                 1       2014-01-20               NaN
# 15737502        9102110                 1       2014-06-25               NaN
# 16056251        9318621                 1       2014-11-19               NaN
# 16056309        9318661                 1       2014-11-19               NaN
# 18324073       10887310                 1       2023-09-01               NaN
# 18733096       11172830                 1       2018-01-26               NaN
# 22739186       14065131                 1       2022-04-25               NaN
# 24444984       15322642                 1       2023-12-01               NaN
# 24585168       15429634                 1       2024-01-22               NaN
# 24719846       15530062                 1       2024-02-28               NaN
# 25111962       15822618                 1       2024-07-06               NaN
# 25677820       OC308455                 5       2015-10-22               NaN
# 26087715       OC450664                 5       2024-01-17               NaN
# 26087739       OC450672                 5       2024-01-17               NaN
# 26089080       OC450973                 5       2024-02-11               NaN
#
#          Partial Date of Birth Company Status  \
# 180543              1955-01-01              D
# 180544              1955-01-01              D
# 915094                     NaT              A
# 2617827             1967-09-01              D
# 2747288             1965-02-01              A
# 2747504             1965-02-01              A
# 3000701             1948-11-01              D
# 3162369             1956-04-01              D
# 3162376             1956-04-01              D
# 3188601             1963-06-01              D
# 5452193             1963-06-01              A
# 5974676             1955-09-01              D
# 6276986             1945-07-01              D
# 6276989             1945-07-01              D
# 6474055             1965-02-01              A
# 6518866             1975-09-01              D
# 6597238             1963-06-01              A
# 6597240             1963-06-01              A
# 6914194             1945-07-01              A
# 10277804            1964-06-01              D
# 10433148            1965-02-01              D
# 11496806            1975-03-01              A
# 11793481            1980-09-01              A
# 12047643            1980-09-01              D
# 12048051            1980-09-01              D
# 12156703            1980-09-01              D
# 12156705            1980-09-01              D
# 12219518            1980-09-01              D
# 12591351            1980-09-01              D
# 12959543            1980-09-01              D
# 13786118            1980-09-01              D
# 13794534            1980-09-01              D
# 13959375                   NaT              A
# 13959376            1978-04-01              A
# 14597227            1980-09-01              D
# 14992835            1980-09-01              D
# 15369891            1980-09-01              D
# 15737502            1956-04-01              D
# 16056251            1980-09-01              D
# 16056309            1980-09-01              D
# 18324073            1975-09-01              A
# 18733096            1980-09-01              A
# 22739186            1980-09-01              D
# 24444984            1963-06-01              A
# 24585168            1991-02-01              A
# 24719846            1991-02-01              A
# 25111962            1993-05-01              A
# 25677820            1980-09-01              A
# 26087715            1980-09-01              A
# 26087739            1980-09-01              A
# 26089080            1980-09-01              A
#
#                                                Company Name  \
# 180543                                 J.W.PELLING LIMITED
# 180544                                 J.W.PELLING LIMITED
# 915094                         CLIMBERS' SHOP LIMITED(THE)
# 2617827                       C.I.S. INTERNATIONAL LIMITED
# 2747288                          GIBBINS & WILDING LIMITED
# 2747504             TRUCK & BUS BUILDER PUBLISHING LIMITED
# 3000701                                   GILTBECK LIMITED
# 3162369               BUSINESS & CORPORATE LEASING LIMITED
# 3162376                             JAGUAR RENTALS LIMITED
# 3188601                    TEMPLE BAR DEVELOPMENTS LIMITED
# 5452193        TEMPLE BAR DEVELOPMENTS (HAMPSHIRE) LIMITED
# 5974676                        CHRISTIANITY ONLINE LIMITED
# 6276986                             MOUNTAIN WORKS LIMITED
# 6276989                             MOUNTAIN WORKS LIMITED
# 6474055                TRUCK & BUS BUILDER REPORTS LIMITED
# 6518866                 BACK TO BASICS CONSULTANCY LIMITED
# 6597238           WESTFIELD PROPERTIES (HAMPSHIRE) LIMITED
# 6597240           WESTFIELD PROPERTIES (HAMPSHIRE) LIMITED
# 6914194                          HOOKED ON GRANITE LIMITED
# 10277804                               JAG RIGGING LIMITED
# 10433148                                      ACVE LIMITED
# 11496806                              MELTHAM SCHOOL'S OUT
# 11793481                                   4ON 365 LIMITED
# 12047643                               CALLQUALITY LIMITED
# 12048051                             IMPOSSIBLE IT LIMITED
# 12156703                          CQ DATA SERVICES LIMITED
# 12156705                          CQ DATA SERVICES LIMITED
# 12219518                         DATA CENTRE POWER LIMITED
# 12591351  SAXON DATA COLOCATION AND DEDICATED SERVER MAN...
# 12959543                                SHL (2013) LIMITED
# 13786118                                   MENDUCA LIMITED
# 13794534                        SAFEHOSTS (LONDON) LIMITED
# 13959375                                       STAND 4 LTD
# 13959376                                       STAND 4 LTD
# 14597227                DATA CENTRE INFRASTRUCTURE LIMITED
# 14992835                              METRO SWITCH LIMITED
# 15369891                     THE FAIRVIEW PUBLIC HOUSE LTD
# 15737502              SKY CONSERVATORY ROOFS AND DOORS LTD
# 16056251                                      DCIN LIMITED
# 16056309            DATACENTRE PRODUCTS & SERVICES LIMITED
# 18324073                               CREATIVE CX LIMITED
# 18733096                                           4ON LTD
# 22739186                         LETSDO TECHNOLOGY LIMITED
# 24444984     DRAY MEWS COTTAGES MANAGEMENT COMPANY LIMITED
# 24585168           GIBB PROPERTIES & DEVELOPMENT'S LIMITED
# 24719846                                     OSK RESIN LTD
# 25111962                               M.J.G CARPENTRY LTD
# 25677820                           SAFE HOSTS INTERNET LLP
# 26087715                                       SANBACH LLP
# 26087739                                          BACH LLP
# 26089080                                        ENTIRE LLP
#
#                          Person Name  Current Age  Current Tenure  \
# 180543      MR MICHAEL JAMES GIBBINS         69.0            33.0
# 180544      MR MICHAEL JAMES GIBBINS         69.0            33.0
# 915094      MR RAYMOND JAMES GIBBINS          NaN            12.0
# 2617827    MR JONATHAN JAMES GIBBINS         57.0            33.0
# 2747288     MR MICHAEL JAMES GIBBINS         59.0            24.0
# 2747504     MR MICHAEL JAMES GIBBINS         59.0            24.0
# 3000701     MR STEPHEN JAMES GIBBINS         76.0            31.0
# 3162369      MR ANDREW JAMES GIBBINS         68.0            31.0
# 3162376      MR ANDREW JAMES GIBBINS         68.0            31.0
# 3188601         ROLAND JAMES GIBBINS         61.0            31.0
# 5452193         ROLAND JAMES GIBBINS         61.0            25.0
# 5974676       DR NIGEL JAMES GIBBINS         69.0            24.0
# 6276986        RAYMOND JAMES GIBBINS         79.0            23.0
# 6276989        RAYMOND JAMES GIBBINS         79.0            20.0
# 6474055     MR MICHAEL JAMES GIBBINS         59.0            23.0
# 6518866          JAMES PETER GIBBINS         49.0            22.0
# 6597238         ROLAND JAMES GIBBINS         61.0            23.0
# 6597240         ROLAND JAMES GIBBINS         61.0            23.0
# 6914194        RAYMOND JAMES GIBBINS         79.0            19.0
# 10277804          JAMES ALAN GIBBINS         60.0            18.0
# 10433148       MICHAEL JAMES GIBBINS         59.0            18.0
# 11496806    MR. PHILIP JAMES GIBBINS         49.0             4.0
# 11793481        MR LEE JAMES GIBBINS         44.0             6.0
# 12047643        MR LEE JAMES GIBBINS         44.0            15.0
# 12048051        MR LEE JAMES GIBBINS         44.0            15.0
# 12156703        MR LEE JAMES GIBBINS         44.0            15.0
# 12156705        MR LEE JAMES GIBBINS         44.0            15.0
# 12219518        MR LEE JAMES GIBBINS         44.0            13.0
# 12591351        MR LEE JAMES GIBBINS         44.0            15.0
# 12959543        MR LEE JAMES GIBBINS         44.0            14.0
# 13786118        MR LEE JAMES GIBBINS         44.0            13.0
# 13794534        MR LEE JAMES GIBBINS         44.0            13.0
# 13959375      MR JAMES PETER GIBBINS          NaN            11.0
# 13959376      MR JAMES PETER GIBBINS         46.0            12.0
# 14597227        MR LEE JAMES GIBBINS         44.0            11.0
# 14992835        MR LEE JAMES GIBBINS         44.0            11.0
# 15369891        MR LEE JAMES GIBBINS         44.0            10.0
# 15737502     MR ANDREW JAMES GIBBINS         68.0            10.0
# 16056251        MR LEE JAMES GIBBINS         44.0            10.0
# 16056309        MR LEE JAMES GIBBINS         44.0            10.0
# 18324073   CHRISTOPHER JAMES GIBBINS         49.0             1.0
# 18733096        MR LEE JAMES GIBBINS         44.0             6.0
# 22739186        MR LEE JAMES GIBBINS         44.0             2.0
# 24444984     MR ROLAND JAMES GIBBINS         61.0             1.0
# 24585168     MR THOMAS JAMES GIBBINS         33.0             0.0
# 24719846     MR THOMAS JAMES GIBBINS         33.0             0.0
# 25111962    MR MATTHEW JAMES GIBBINS         31.0             0.0
# 25677820        MR LEE JAMES GIBBINS         44.0             9.0
# 26087715        MR LEE JAMES GIBBINS         44.0             0.0
# 26087739        MR LEE JAMES GIBBINS         44.0             0.0
# 26089080        MR LEE JAMES GIBBINS         44.0             0.0
#
#           Time Since Leaving  Total Tenure
# 180543                   NaN           NaN
# 180544                   NaN           NaN
# 915094                   NaN           NaN
# 2617827                  NaN           NaN
# 2747288                  NaN           NaN
# 2747504                  NaN           NaN
# 3000701                  NaN           NaN
# 3162369                  NaN           NaN
# 3162376                  NaN           NaN
# 3188601                  NaN           NaN
# 5452193                  NaN           NaN
# 5974676                  NaN           NaN
# 6276986                  NaN           NaN
# 6276989                  NaN           NaN
# 6474055                  NaN           NaN
# 6518866                  NaN           NaN
# 6597238                  NaN           NaN
# 6597240                  NaN           NaN
# 6914194                  NaN           NaN
# 10277804                 NaN           NaN
# 10433148                 NaN           NaN
# 11496806                 NaN           NaN
# 11793481                 NaN           NaN
# 12047643                 NaN           NaN
# 12048051                 NaN           NaN
# 12156703                 NaN           NaN
# 12156705                 NaN           NaN
# 12219518                 NaN           NaN
# 12591351                 NaN           NaN
# 12959543                 NaN           NaN
# 13786118                 NaN           NaN
# 13794534                 NaN           NaN
# 13959375                 NaN           NaN
# 13959376                 NaN           NaN
# 14597227                 NaN           NaN
# 14992835                 NaN           NaN
# 15369891                 NaN           NaN
# 15737502                 NaN           NaN
# 16056251                 NaN           NaN
# 16056309                 NaN           NaN
# 18324073                 NaN           NaN
# 18733096                 NaN           NaN
# 22739186                 NaN           NaN
# 24444984                 NaN           NaN
# 24585168                 NaN           NaN
# 24719846                 NaN           NaN
# 25111962                 NaN           NaN
# 25677820                 NaN           NaN
# 26087715                 NaN           NaN
# 26087739                 NaN           NaN
# 26089080                 NaN           NaN

# %%
data[data['Person Name'].str.contains("GIBBINS", case=False, na=False)][data['Partial Date of Birth'].dt.year == 1992]
# Out:
# C:\Users\jgibb\AppData\Local\Temp\ipykernel_20960\1921717921.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['Person Name'].str.contains("GIBBINS", case=False, na=False)][data['Partial Date of Birth'].dt.year == 1992]
#          Company Number  Appointment Type Appointment Date  Resignation Date  \
# 8038982         4899448                 1       2024-05-10               NaN
# 8079668         4917873                 1       2022-12-14               NaN
# 14040349        7986149                 1       2012-03-12               NaN
# 15308058        8811285                 1       2013-12-11               NaN
# 22896174       14181098                 1       2022-06-19               NaN
# 23712926       14780851                 1       2023-04-04               NaN
# 25187083       15877359                 1       2024-08-05               NaN
#
#          Partial Date of Birth Company Status  \
# 8038982             1992-09-01              A
# 8079668             1992-09-01              A
# 14040349            1992-08-01              D
# 15308058            1992-08-01              A
# 22896174            1992-09-01              A
# 23712926            1992-09-01              D
# 25187083            1992-09-01              A
#
#                                          Company Name  \
# 8038982                 HIGH-TEK SCAFFOLDING LIMITED
# 8079668   HIGH-TEK SCAFFOLDING (BOURNEMOUTH) LIMITED
# 14040349                             IFO TRADING LTD
# 15308058                        PRODIS SOLUTIONS LTD
# 22896174                  HIGH-TEK HIRE SERVICES LTD
# 23712926           THE COMPOSITE AND VERANDA CO. LTD
# 25187083                   HOME OAK DEVELOPMENTS LTD
#
#                        Person Name  Current Age  Current Tenure  \
# 8038982      MR MAX MARKUS GIBBINS         32.0             0.0
# 8079668      MR MAX MARKUS GIBBINS         32.0             1.0
# 14040349  MR SAMUEL DONALD GIBBINS         32.0            12.0
# 15308058  MR SAMUEL DONALD GIBBINS         32.0            11.0
# 22896174     MR MAX MARKUS GIBBINS         32.0             2.0
# 23712926     MR MAX MARKUS GIBBINS         32.0             1.0
# 25187083     MR MAX MARKUS GIBBINS         32.0             0.0
#
#           Time Since Leaving  Total Tenure
# 8038982                  NaN           NaN
# 8079668                  NaN           NaN
# 14040349                 NaN           NaN
# 15308058                 NaN           NaN
# 22896174                 NaN           NaN
# 23712926                 NaN           NaN
# 25187083                 NaN           NaN

# %%
# unique_company_numbers = data['Company Number'].unique()
print(f'{unique_company_numbers[:5]}... ({len(unique_company_numbers)})')
# np.savetxt('unique_company_ids.csv', unique_company_numbers, delimiter=",", fmt='%s')
# unique_company_ids = np.loadtxt('unique_company_ids.csv', dtype=int)
# Out:
# [6 58 86 118 121]... (14239717)

# %%
data[data.duplicated()]
# Out:
#          Company Number  Appointment Type Appointment Date  Resignation Date  \
# 34788            152062                 0       2009-10-31               NaN
# 48785            191751                 1       2019-04-08               NaN
# 56257            213567                 1       2023-09-06               NaN
# 57415            216761                 1       2010-09-10               NaN
# 64717            236303                 1       2020-11-01               NaN
# ...                 ...               ...              ...               ...
# 26071174       OC445050                 4       2024-07-03               NaN
# 26071243       OC445050                 4       2024-06-16               NaN
# 26072198       OC445370                 4       2023-06-30               NaN
# 26075327       OC446431                 5       2023-03-21               NaN
# 26082106       OC448825                 5       2023-08-24               NaN
#
#          Partial Date of Birth Company Status  \
# 34788                      NaT              D
# 48785               1976-08-01              D
# 56257               1959-12-01              A
# 57415               1966-06-01              D
# 64717               1978-12-01              A
# ...                        ...            ...
# 26071174            1985-04-01              A
# 26071243            2005-07-01              A
# 26072198                   NaT              A
# 26075327            1994-08-01              D
# 26082106                   NaT              A
#
#                                           Company Name  \
# 34788                             ROBOT NO. 4 LIMITED
# 48785                         REG VARDY (AMC) LIMITED
# 56257           THE CARSHALTON COURTS COMPANY LIMITED
# 57415                                  YASDAN LIMITED
# 64717     UNITED KINGDOM TOBACCO COMPANY LIMITED(THE)
# ...                                                ...
# 26071174                   CLASSTUTOR PARTNERSHIP LLP
# 26071243                   CLASSTUTOR PARTNERSHIP LLP
# 26072198      MOORE KINGSTON SMITH GROUP HOLDINGS LLP
# 26075327                             IT TECHNOLGY LLP
# 26082106                           ICCACK EMBASSY LLP
#
#                                                 Person Name  Current Age  \
# 34788                              MISS SARAH LOUISE MORTON          NaN
# 48785                                  MR MARK SIMON WILLIS         48.0
# 56257                                MR KEVIN RICHARD POWER         65.0
# 57415                       MR ROGER CHRISTOPHER HARRINGTON         58.0
# 64717                          MR CHRISTIAN MARK WOOLFENDEN         46.0
# ...                                                     ...          ...
# 26071174                        MISS LAETITIA AFFOYA DESSOU         39.0
# 26071243                           MISS TEJASWINI RAJ MOHAN         19.0
# 26072198    MEMBERS COMPANY 2023 LIMITED AS TRUSTEE FOR ...          NaN
# 26075327                                MR IBRAHIM ALKHALAF         30.0
# 26082106    INTERNATIONAL CRIMINAL COURT AGAINST CHILD K...          NaN
#
#           Current Tenure  Time Since Leaving  Total Tenure
# 34788               15.0                 NaN           NaN
# 48785                5.0                 NaN           NaN
# 56257                1.0                 NaN           NaN
# 57415               14.0                 NaN           NaN
# 64717                4.0                 NaN           NaN
# ...                  ...                 ...           ...
# 26071174             0.0                 NaN           NaN
# 26071243             0.0                 NaN           NaN
# 26072198             1.0                 NaN           NaN
# 26075327             1.0                 NaN           NaN
# 26082106             1.0                 NaN           NaN
#
# [3571 rows x 12 columns]

# %%
data[data['Person Name'].str.contains(r"MISS SARAH LOUISE MORTON", case=False, na=False)]
# Out:
#         Company Number  Appointment Type Appointment Date  Resignation Date  \
# 34787           152062                 0       2009-10-31               NaN
# 34788           152062                 0       2009-10-31               NaN
# 43622           176811                 0       2009-10-31               NaN
# 73892           259138                 0       2009-10-31               NaN
# 74952           261879                 0       2009-10-31               NaN
# 111441          353187                 0       2009-10-31               NaN
# 234889          562908                 0       2009-10-31               NaN
# 1479400        1946674                 0       2009-10-31               NaN
#
#         Partial Date of Birth Company Status  \
# 34787                     NaT              D
# 34788                     NaT              D
# 43622                     NaT              D
# 73892                     NaT              D
# 74952                     NaT              D
# 111441                    NaT              D
# 234889                    NaT              D
# 1479400                   NaT              D
#
#                                               Company Name  \
# 34787                                 ROBOT NO. 4 LIMITED
# 34788                                 ROBOT NO. 4 LIMITED
# 43622                      BLADES EAST AND BLADES LIMITED
# 73892                                MCT (EXPORT) LIMITED
# 74952                                 ROBOT NO. 5 LIMITED
# 111441                                ROBOT NO. 2 LIMITED
# 234889   WADDINGTONS BUSINESS FORMS (CLAYTON WEST) LIMI...
# 1479400                               ROBOT NO. 8 LIMITED
#
#                       Person Name  Current Age  Current Tenure  \
# 34787    MISS SARAH LOUISE MORTON          NaN            15.0
# 34788    MISS SARAH LOUISE MORTON          NaN            15.0
# 43622    MISS SARAH LOUISE MORTON          NaN            15.0
# 73892    MISS SARAH LOUISE MORTON          NaN            15.0
# 74952    MISS SARAH LOUISE MORTON          NaN            15.0
# 111441   MISS SARAH LOUISE MORTON          NaN            15.0
# 234889   MISS SARAH LOUISE MORTON          NaN            15.0
# 1479400  MISS SARAH LOUISE MORTON          NaN            15.0
#
#          Time Since Leaving  Total Tenure
# 34787                   NaN           NaN
# 34788                   NaN           NaN
# 43622                   NaN           NaN
# 73892                   NaN           NaN
# 74952                   NaN           NaN
# 111441                  NaN           NaN
# 234889                  NaN           NaN
# 1479400                 NaN           NaN

# %%
# update_file = 'Prod198_3850.txt'

# person_record_colspecs = [ (0,8), (15,17), (17,19), (43,51), (75,83), (83,91), (111,1249) ]
# person_record_names = [ "Company Number", "Old Appointment Type", "New Appointment Type", "Partial Date of Birth", "Appointment Date", "Resignation Date", "Variable Data" ]
# company_record_colspecs = [ (0,8), (9,10), (40,201) ]
# company_record_names = [ "Company Number", "Company Status", "Company Name" ]

# def detect_colspec(line):
#     if line[8] == '1':
#         return company_record_colspecs, company_record_names
#     elif line[8] == '2':
#         return person_record_colspecs, person_record_names
#     else:
#         print(line)
#         return [],[]

# def process_entire_file(file_path):
#     company_records = []
#     person_records = []

#     with open(file_path, 'r') as file:
#         for line in tqdm(file, desc="Processing lines", mininterval=1):
#             colspecs, names = detect_colspec(line)
#             if colspecs != []:
#                 parsed_line = pd.read_fwf(pd.io.common.StringIO(line), colspecs=colspecs, names=names)
#                 if "Company Status" in names:
#                     company_records.append(parsed_line)
#                 else:
#                     person_records.append(parsed_line)

#     # Convert to DataFrames
#     print(f'{pd.Timestamp.now()}: Converting to DataFrames')
#     df_company = pd.concat(company_records, ignore_index=True) if company_records else pd.DataFrame(columns=company_record_names)
#     df_person = pd.concat(person_records, ignore_index=True) if person_records else pd.DataFrame(columns=person_record_names)

#     return df_company, df_person

# if "update_data" not in globals():
#     update_data = pd.DataFrame()

# df_company, df_person = process_entire_file(update_file)

# print(f'{pd.Timestamp.now()}: Merging new data')
# new_data = pd.merge(df_person, df_company, on="Company Number", how="inner")

# print(f'{pd.Timestamp.now()}: Cleaning data')
# new_data['Company Status'] = new_data['Company Status'].fillna('A')
# new_data['Person Name'] = new_data['Variable Data'].str.split('<<<<').str[0].str.replace('<',' ')
# new_data['Company Name'] = new_data['Company Name'].str.replace('<',' ')
# new_data = new_data.drop(['Variable Data'], axis=1)

# print(f'{pd.Timestamp.now()}: Making new columns')
# new_data['Partial Date of Birth'] = pd.to_datetime(new_data['Partial Date of Birth'].dropna().astype(int).astype(str), format='%Y%m', errors='coerce')
# new_data['Appointment Date'] = pd.to_datetime(new_data['Appointment Date'].astype(int).astype(str), format='%Y%m%d', errors='coerce')
# new_data['Resignation Date'] = pd.to_datetime(new_data['Resignation Date'].fillna(30000101).astype(int).astype(str), format='%Y%m%d', errors='coerce')
# today = pd.Timestamp.now()
# new_data['Current Age'] = new_data['Partial Date of Birth'].apply(lambda x: today.year - x.year - ((today.month, today.day) < (x.month, x.day)) if pd.notnull(x) else np.nan)
# def calculate_tenure(row):
#     if pd.isnull(row['Resignation Date']):
#         current_tenure = today.year - row['Appointment Date'].year - ((today.month, today.day) < (row['Appointment Date'].month, row['Appointment Date'].day))
#         return pd.Series({'Current Tenure': current_tenure, 'Time Since Leaving': np.nan, 'Total Tenure': np.nan})
#     else:
#         time_since_leaving = today.year - row['Resignation Date'].year - ((today.month, today.day) < (row['Resignation Date'].month, row['Resignation Date'].day))
#         total_tenure = (row['Resignation Date'] - row['Appointment Date']).days / 365.25  # Total tenure in years
#         return pd.Series({'Current Tenure': np.nan, 'Time Since Leaving': time_since_leaving, 'Total Tenure': total_tenure})
# new_data[['Current Tenure', 'Time Since Leaving', 'Total Tenure']] = new_data.apply(calculate_tenure, axis=1)

# print(f'{pd.Timestamp.now()}: Merging data')
# update_data = pd.concat([update_data, new_data], ignore_index=True)
# Out:
# Processing lines: 0it [00:00, ?it/s]
# DDDDUPDT385020241212
# Processing lines: 20326it [00:27, 727.15it/s]
# 9999999900020324
#
# 2024-12-13 09:53:40.066802: Converting to DataFrames
# 2024-12-13 09:53:44.296534: Merging new data
# 2024-12-13 09:53:44.313619: Cleaning data
